# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import argparse
import numpy as np
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import os
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.functional as F
import numpy as np
import torch.optim as optim
import math
import torchvision
import torchvision.transforms as transforms

# %%
batch_size=128
epoch=55
learning_rate=0.001
momentum=0.9
no_cuda=False
log_schedule=100
seed=1
model_name=None
want_to_test=False
epoch_55=False
num_classes=10

# %%
class fire(nn.Module):
    def __init__(self, inplanes, squeeze_planes, expand_planes):
        super(fire, self).__init__()
        self.conv1 = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1, stride=1)
        self.bn1 = nn.BatchNorm2d(squeeze_planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(squeeze_planes, expand_planes, kernel_size=1, stride=1)
        self.bn2 = nn.BatchNorm2d(expand_planes)
        self.conv3 = nn.Conv2d(squeeze_planes, expand_planes, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(expand_planes)
        self.relu2 = nn.ReLU(inplace=True)

        # using MSR initilization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.in_channels
                m.weight.data.normal_(0, math.sqrt(2./n))

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        out1 = self.conv2(x)
        out1 = self.bn2(out1)
        out2 = self.conv3(x)
        out2 = self.bn3(out2)
        out = torch.cat([out1, out2], 1)
        out = self.relu2(out)
        return out


class SqueezeNet(nn.Module):
    def __init__(self):
        super(SqueezeNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 96, kernel_size=3, stride=1, padding=1) # 32
        self.bn1 = nn.BatchNorm2d(96)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2) # 16
        self.fire2 = fire(96, 16, 64)
        self.fire3 = fire(128, 16, 64)
        self.fire4 = fire(128, 32, 128)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2) # 8
        self.fire5 = fire(256, 32, 128)
        self.fire6 = fire(256, 48, 192)
        self.fire7 = fire(384, 48, 192)
        self.fire8 = fire(384, 64, 256)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2) # 4
        self.fire9 = fire(512, 64, 256)
        self.conv2 = nn.Conv2d(512, 10, kernel_size=1, stride=1)
        self.avg_pool = nn.AvgPool2d(kernel_size=4, stride=4)
        self.softmax = nn.LogSoftmax(dim=1)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.in_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()


    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool1(x)
        x = self.fire2(x)
        x = self.fire3(x)
        x = self.fire4(x)
        x = self.maxpool2(x)
        x = self.fire5(x)
        x = self.fire6(x)
        x = self.fire7(x)
        x = self.fire8(x)
        x = self.maxpool3(x)
        x = self.fire9(x)
        x = self.conv2(x)
        x = self.avg_pool(x)
        x = self.softmax(x)
        return x

def fire_layer(inp, s, e):
    f = fire(inp, s, e)
    return f

def squeezenet(pretrained=False):
    net = SqueezeNet()
    # inp = Variable(torch.randn(64,3,32,32))
    # out = net.forward(inp)
    # print(out.size())
    return net


cuda = torch.cuda.is_available()

torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

net  = SqueezeNet()
net.cuda()


    
#print(net)
# Out:
# SqueezeNet(
#   (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fire2): fire(
#     (conv1): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (fire3): fire(
#     (conv1): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (fire4): fire(
#     (conv1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fire5): fire(
#     (conv1): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (fire6): fire(
#     (conv1): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (fire7): fire(
#     (conv1): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (fire8): fire(
#     (conv1): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fire9): fire(
#     (conv1): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#   )
#   (conv2): Conv2d(512, 10, kernel_size=(1, 1), stride=(1, 1))
#   (avg_pool): AvgPool2d(kernel_size=4, stride=4, padding=0)
#   (softmax): LogSoftmax()
# )

# %%
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0)
criterion = nn.CrossEntropyLoss()
device = 'cuda' if torch.cuda.is_available() else 'cpu'

def train(epoch):


    correct = 0
    net.train()
    for b_idx, (data, targets) in enumerate(train_loader):

        data, targets = data.cuda(), targets.cuda()
        # convert the data and targets into Variable and cuda form
        data, targets = Variable(data), Variable(targets)

        # train the network
        optimizer.zero_grad()
        scores = net.forward(data)
        scores = scores.view(-1, num_classes)
        loss = criterion(scores, targets)

        # compute the accuracy
        pred = scores.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(targets.data).cpu().sum()

        loss.backward()
        optimizer.step()

        if b_idx % log_schedule == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (b_idx+1) * len(data), len(train_loader.dataset),
                100. * (b_idx+1)*len(data) / len(train_loader.dataset), loss.item()))



    # now that the epoch is completed plot the accuracy
    train_accuracy = correct / float(len(train_loader.dataset))
    #print("training accuracy ({:.2f}%)".format(100*train_accuracy))
    return (train_accuracy*100.0)

def test(loader):
    net.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in loader:
            data, target = data.to(device), target.to(device)
            output = net(data)
            output = output.view(-1, num_classes)
            test_loss += criterion(output, target).item() # sum up batch loss
            #test_loss += nn.NLLLoss(output, target).item()
            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).sum().item()

        test_loss /= len(loader.dataset)
        accuracy = 100. * correct / len(loader.dataset)
        print(f'Test set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(loader.dataset)} ({accuracy:.2f}%)')
    return accuracy

# %%
for i in range(1,126):
    train(i)
    test(train_loader)
    test(test_loader)
# Out:
# Train Epoch: 1 [128/50000 (0%)]	Loss: 2.656236
# Train Epoch: 1 [12928/50000 (26%)]	Loss: 2.116799
# Train Epoch: 1 [25728/50000 (51%)]	Loss: 2.032637
# Train Epoch: 1 [38528/50000 (77%)]	Loss: 1.876766
# Test set: Average loss: 0.0143, Accuracy: 15555/50000 (31.11%)
# Test set: Average loss: 0.0181, Accuracy: 3193/10000 (31.93%)
# Train Epoch: 2 [128/50000 (0%)]	Loss: 1.878771
# Train Epoch: 2 [12928/50000 (26%)]	Loss: 1.798710
# Train Epoch: 2 [25728/50000 (51%)]	Loss: 1.861210
# Train Epoch: 2 [38528/50000 (77%)]	Loss: 1.739033
# Test set: Average loss: 0.0132, Accuracy: 18596/50000 (37.19%)
# Test set: Average loss: 0.0166, Accuracy: 3841/10000 (38.41%)
# Train Epoch: 3 [128/50000 (0%)]	Loss: 1.703263
# Train Epoch: 3 [12928/50000 (26%)]	Loss: 1.592589
# Train Epoch: 3 [25728/50000 (51%)]	Loss: 1.749890
# Train Epoch: 3 [38528/50000 (77%)]	Loss: 1.662410
# Test set: Average loss: 0.0125, Accuracy: 20393/50000 (40.79%)
# Test set: Average loss: 0.0157, Accuracy: 4105/10000 (41.05%)
# Train Epoch: 4 [128/50000 (0%)]	Loss: 1.612532
# Train Epoch: 4 [12928/50000 (26%)]	Loss: 1.562170
# Train Epoch: 4 [25728/50000 (51%)]	Loss: 1.484377
# Train Epoch: 4 [38528/50000 (77%)]	Loss: 1.598935
# Test set: Average loss: 0.0120, Accuracy: 21507/50000 (43.01%)
# Test set: Average loss: 0.0149, Accuracy: 4440/10000 (44.40%)
# Train Epoch: 5 [128/50000 (0%)]	Loss: 1.436917
# Train Epoch: 5 [12928/50000 (26%)]	Loss: 1.513977
# Train Epoch: 5 [25728/50000 (51%)]	Loss: 1.470776
# Train Epoch: 5 [38528/50000 (77%)]	Loss: 1.533079
# Test set: Average loss: 0.0114, Accuracy: 23020/50000 (46.04%)
# Test set: Average loss: 0.0145, Accuracy: 4664/10000 (46.64%)
# Train Epoch: 6 [128/50000 (0%)]	Loss: 1.324844
# Train Epoch: 6 [12928/50000 (26%)]	Loss: 1.520218
# Train Epoch: 6 [25728/50000 (51%)]	Loss: 1.361805
# Train Epoch: 6 [38528/50000 (77%)]	Loss: 1.453340
# Test set: Average loss: 0.0110, Accuracy: 23872/50000 (47.74%)
# Test set: Average loss: 0.0139, Accuracy: 4904/10000 (49.04%)
# Train Epoch: 7 [128/50000 (0%)]	Loss: 1.572168
# Train Epoch: 7 [12928/50000 (26%)]	Loss: 1.369933
# Train Epoch: 7 [25728/50000 (51%)]	Loss: 1.437440
# Train Epoch: 7 [38528/50000 (77%)]	Loss: 1.409100
# Test set: Average loss: 0.0105, Accuracy: 25518/50000 (51.04%)
# Test set: Average loss: 0.0134, Accuracy: 5170/10000 (51.70%)
# Train Epoch: 8 [128/50000 (0%)]	Loss: 1.474558
# Train Epoch: 8 [12928/50000 (26%)]	Loss: 1.344161
# Train Epoch: 8 [25728/50000 (51%)]	Loss: 1.339761
# Train Epoch: 8 [38528/50000 (77%)]	Loss: 1.297313
# Test set: Average loss: 0.0102, Accuracy: 26127/50000 (52.25%)
# Test set: Average loss: 0.0130, Accuracy: 5316/10000 (53.16%)
# Train Epoch: 9 [128/50000 (0%)]	Loss: 1.310905
# Train Epoch: 9 [12928/50000 (26%)]	Loss: 1.388708
# Train Epoch: 9 [25728/50000 (51%)]	Loss: 1.353833
# Train Epoch: 9 [38528/50000 (77%)]	Loss: 1.246586
# Test set: Average loss: 0.0100, Accuracy: 26794/50000 (53.59%)
# Test set: Average loss: 0.0127, Accuracy: 5434/10000 (54.34%)
# Train Epoch: 10 [128/50000 (0%)]	Loss: 1.314434
# Train Epoch: 10 [12928/50000 (26%)]	Loss: 1.286913
# Train Epoch: 10 [25728/50000 (51%)]	Loss: 1.330579
# Train Epoch: 10 [38528/50000 (77%)]	Loss: 1.179879
# Test set: Average loss: 0.0095, Accuracy: 27721/50000 (55.44%)
# Test set: Average loss: 0.0122, Accuracy: 5614/10000 (56.14%)
# Train Epoch: 11 [128/50000 (0%)]	Loss: 1.309994
# Train Epoch: 11 [12928/50000 (26%)]	Loss: 1.263210
# Train Epoch: 11 [25728/50000 (51%)]	Loss: 1.229423
# Train Epoch: 11 [38528/50000 (77%)]	Loss: 1.151048
# Test set: Average loss: 0.0094, Accuracy: 28308/50000 (56.62%)
# Test set: Average loss: 0.0121, Accuracy: 5678/10000 (56.78%)
# Train Epoch: 12 [128/50000 (0%)]	Loss: 1.192420
# Train Epoch: 12 [12928/50000 (26%)]	Loss: 1.247928
# Train Epoch: 12 [25728/50000 (51%)]	Loss: 1.190344
# Train Epoch: 12 [38528/50000 (77%)]	Loss: 1.239499
# Test set: Average loss: 0.0090, Accuracy: 29066/50000 (58.13%)
# Test set: Average loss: 0.0117, Accuracy: 5775/10000 (57.75%)
# Train Epoch: 13 [128/50000 (0%)]	Loss: 1.101757
# Train Epoch: 13 [12928/50000 (26%)]	Loss: 1.263777
# Train Epoch: 13 [25728/50000 (51%)]	Loss: 1.246158
# Train Epoch: 13 [38528/50000 (77%)]	Loss: 1.171059
# Test set: Average loss: 0.0089, Accuracy: 29479/50000 (58.96%)
# Test set: Average loss: 0.0114, Accuracy: 5865/10000 (58.65%)
# Train Epoch: 14 [128/50000 (0%)]	Loss: 1.291206
# Train Epoch: 14 [12928/50000 (26%)]	Loss: 1.130980
# Train Epoch: 14 [25728/50000 (51%)]	Loss: 1.209829
# Train Epoch: 14 [38528/50000 (77%)]	Loss: 1.106608
# Test set: Average loss: 0.0086, Accuracy: 30200/50000 (60.40%)
# Test set: Average loss: 0.0113, Accuracy: 5967/10000 (59.67%)
# Train Epoch: 15 [128/50000 (0%)]	Loss: 1.183722
# Train Epoch: 15 [12928/50000 (26%)]	Loss: 1.186713
# Train Epoch: 15 [25728/50000 (51%)]	Loss: 1.096856
# Train Epoch: 15 [38528/50000 (77%)]	Loss: 0.977004
# Test set: Average loss: 0.0084, Accuracy: 30604/50000 (61.21%)
# Test set: Average loss: 0.0108, Accuracy: 6112/10000 (61.12%)
# Train Epoch: 16 [128/50000 (0%)]	Loss: 1.072287
# Train Epoch: 16 [12928/50000 (26%)]	Loss: 1.115701
# Train Epoch: 16 [25728/50000 (51%)]	Loss: 1.144821
# Train Epoch: 16 [38528/50000 (77%)]	Loss: 0.898874
# Test set: Average loss: 0.0083, Accuracy: 30795/50000 (61.59%)
# Test set: Average loss: 0.0107, Accuracy: 6134/10000 (61.34%)
# Train Epoch: 17 [128/50000 (0%)]	Loss: 1.104543
# Train Epoch: 17 [12928/50000 (26%)]	Loss: 1.061969
# Train Epoch: 17 [25728/50000 (51%)]	Loss: 0.996431
# Train Epoch: 17 [38528/50000 (77%)]	Loss: 1.066562
# Test set: Average loss: 0.0081, Accuracy: 31305/50000 (62.61%)
# Test set: Average loss: 0.0107, Accuracy: 6182/10000 (61.82%)
# Train Epoch: 18 [128/50000 (0%)]	Loss: 0.927857
# Train Epoch: 18 [12928/50000 (26%)]	Loss: 1.116498
# Train Epoch: 18 [25728/50000 (51%)]	Loss: 1.114146
# Train Epoch: 18 [38528/50000 (77%)]	Loss: 0.853010
# Test set: Average loss: 0.0082, Accuracy: 31215/50000 (62.43%)
# Test set: Average loss: 0.0108, Accuracy: 6187/10000 (61.87%)
# Train Epoch: 19 [128/50000 (0%)]	Loss: 1.020507
# Train Epoch: 19 [12928/50000 (26%)]	Loss: 1.024132
# Train Epoch: 19 [25728/50000 (51%)]	Loss: 1.125857
# Train Epoch: 19 [38528/50000 (77%)]	Loss: 0.866413
# Test set: Average loss: 0.0078, Accuracy: 31956/50000 (63.91%)
# Test set: Average loss: 0.0103, Accuracy: 6316/10000 (63.16%)
# Train Epoch: 20 [128/50000 (0%)]	Loss: 0.962847
# Train Epoch: 20 [12928/50000 (26%)]	Loss: 1.038320
# Train Epoch: 20 [25728/50000 (51%)]	Loss: 0.879773
# Train Epoch: 20 [38528/50000 (77%)]	Loss: 1.046223
# Test set: Average loss: 0.0076, Accuracy: 32463/50000 (64.93%)
# Test set: Average loss: 0.0101, Accuracy: 6432/10000 (64.32%)
# Train Epoch: 21 [128/50000 (0%)]	Loss: 1.147784
# Train Epoch: 21 [12928/50000 (26%)]	Loss: 0.912034
# Train Epoch: 21 [25728/50000 (51%)]	Loss: 0.920944
# Train Epoch: 21 [38528/50000 (77%)]	Loss: 0.962761
# Test set: Average loss: 0.0075, Accuracy: 32837/50000 (65.67%)
# Test set: Average loss: 0.0098, Accuracy: 6502/10000 (65.02%)
# Train Epoch: 22 [128/50000 (0%)]	Loss: 0.944213
# Train Epoch: 22 [12928/50000 (26%)]	Loss: 1.006606
# Train Epoch: 22 [25728/50000 (51%)]	Loss: 0.957594
# Train Epoch: 22 [38528/50000 (77%)]	Loss: 0.777772
# Test set: Average loss: 0.0074, Accuracy: 33125/50000 (66.25%)
# Test set: Average loss: 0.0096, Accuracy: 6546/10000 (65.46%)
# Train Epoch: 23 [128/50000 (0%)]	Loss: 0.855059
# Train Epoch: 23 [12928/50000 (26%)]	Loss: 0.939211
# Train Epoch: 23 [25728/50000 (51%)]	Loss: 1.012596
# Train Epoch: 23 [38528/50000 (77%)]	Loss: 1.049014
# Test set: Average loss: 0.0073, Accuracy: 33388/50000 (66.78%)
# Test set: Average loss: 0.0095, Accuracy: 6656/10000 (66.56%)
# Train Epoch: 24 [128/50000 (0%)]	Loss: 1.010249
# Train Epoch: 24 [12928/50000 (26%)]	Loss: 0.781460
# Train Epoch: 24 [25728/50000 (51%)]	Loss: 0.970588
# Train Epoch: 24 [38528/50000 (77%)]	Loss: 0.944843
# Test set: Average loss: 0.0072, Accuracy: 33613/50000 (67.23%)
# Test set: Average loss: 0.0095, Accuracy: 6614/10000 (66.14%)
# Train Epoch: 25 [128/50000 (0%)]	Loss: 1.053574
# Train Epoch: 25 [12928/50000 (26%)]	Loss: 0.912643
# Train Epoch: 25 [25728/50000 (51%)]	Loss: 0.810532
# Train Epoch: 25 [38528/50000 (77%)]	Loss: 0.983202
# Test set: Average loss: 0.0070, Accuracy: 33949/50000 (67.90%)
# Test set: Average loss: 0.0093, Accuracy: 6711/10000 (67.11%)
# Train Epoch: 26 [128/50000 (0%)]	Loss: 0.928430
# Train Epoch: 26 [12928/50000 (26%)]	Loss: 0.905949
# Train Epoch: 26 [25728/50000 (51%)]	Loss: 0.939827
# Train Epoch: 26 [38528/50000 (77%)]	Loss: 0.818721
# Test set: Average loss: 0.0069, Accuracy: 34264/50000 (68.53%)
# Test set: Average loss: 0.0092, Accuracy: 6739/10000 (67.39%)
# Train Epoch: 27 [128/50000 (0%)]	Loss: 0.830507
# Train Epoch: 27 [12928/50000 (26%)]	Loss: 0.887552
# Train Epoch: 27 [25728/50000 (51%)]	Loss: 0.863813
# Train Epoch: 27 [38528/50000 (77%)]	Loss: 0.831302
# Test set: Average loss: 0.0068, Accuracy: 34372/50000 (68.74%)
# Test set: Average loss: 0.0091, Accuracy: 6792/10000 (67.92%)
# Train Epoch: 28 [128/50000 (0%)]	Loss: 0.836571
# Train Epoch: 28 [12928/50000 (26%)]	Loss: 0.995114
# Train Epoch: 28 [25728/50000 (51%)]	Loss: 0.937544
# Train Epoch: 28 [38528/50000 (77%)]	Loss: 0.878330
# Test set: Average loss: 0.0067, Accuracy: 34696/50000 (69.39%)
# Test set: Average loss: 0.0090, Accuracy: 6821/10000 (68.21%)
# Train Epoch: 29 [128/50000 (0%)]	Loss: 0.918082
# Train Epoch: 29 [12928/50000 (26%)]	Loss: 0.719702
# Train Epoch: 29 [25728/50000 (51%)]	Loss: 0.856832
# Train Epoch: 29 [38528/50000 (77%)]	Loss: 0.864311
# Test set: Average loss: 0.0067, Accuracy: 34685/50000 (69.37%)
# Test set: Average loss: 0.0089, Accuracy: 6880/10000 (68.80%)
# Train Epoch: 30 [128/50000 (0%)]	Loss: 0.892664
# Train Epoch: 30 [12928/50000 (26%)]	Loss: 0.964808
# Train Epoch: 30 [25728/50000 (51%)]	Loss: 0.895049
# Train Epoch: 30 [38528/50000 (77%)]	Loss: 0.869364
# Test set: Average loss: 0.0067, Accuracy: 34606/50000 (69.21%)
# Test set: Average loss: 0.0089, Accuracy: 6902/10000 (69.02%)
# Train Epoch: 31 [128/50000 (0%)]	Loss: 0.774377
# Train Epoch: 31 [12928/50000 (26%)]	Loss: 1.001059
# Train Epoch: 31 [25728/50000 (51%)]	Loss: 0.721542
# Train Epoch: 31 [38528/50000 (77%)]	Loss: 0.775769
# Test set: Average loss: 0.0065, Accuracy: 35294/50000 (70.59%)
# Test set: Average loss: 0.0088, Accuracy: 6898/10000 (68.98%)
# Train Epoch: 32 [128/50000 (0%)]	Loss: 0.859283
# Train Epoch: 32 [12928/50000 (26%)]	Loss: 0.838178
# Train Epoch: 32 [25728/50000 (51%)]	Loss: 0.944502
# Train Epoch: 32 [38528/50000 (77%)]	Loss: 0.740400
# Test set: Average loss: 0.0063, Accuracy: 35581/50000 (71.16%)
# Test set: Average loss: 0.0086, Accuracy: 7003/10000 (70.03%)
# Train Epoch: 33 [128/50000 (0%)]	Loss: 0.802082
# Train Epoch: 33 [12928/50000 (26%)]	Loss: 0.972817
# Train Epoch: 33 [25728/50000 (51%)]	Loss: 0.791358
# Train Epoch: 33 [38528/50000 (77%)]	Loss: 0.924078
# Test set: Average loss: 0.0064, Accuracy: 35353/50000 (70.71%)
# Test set: Average loss: 0.0088, Accuracy: 6971/10000 (69.71%)
# Train Epoch: 34 [128/50000 (0%)]	Loss: 0.809939
# Train Epoch: 34 [12928/50000 (26%)]	Loss: 0.858843
# Train Epoch: 34 [25728/50000 (51%)]	Loss: 0.836609
# Train Epoch: 34 [38528/50000 (77%)]	Loss: 0.893057
# Test set: Average loss: 0.0064, Accuracy: 35538/50000 (71.08%)
# Test set: Average loss: 0.0087, Accuracy: 6921/10000 (69.21%)
# Train Epoch: 35 [128/50000 (0%)]	Loss: 0.794284
# Train Epoch: 35 [12928/50000 (26%)]	Loss: 0.909103
# Train Epoch: 35 [25728/50000 (51%)]	Loss: 0.912340
# Train Epoch: 35 [38528/50000 (77%)]	Loss: 0.778384
# Test set: Average loss: 0.0062, Accuracy: 36009/50000 (72.02%)
# Test set: Average loss: 0.0084, Accuracy: 7037/10000 (70.37%)
# Train Epoch: 36 [128/50000 (0%)]	Loss: 0.642111
# Train Epoch: 36 [12928/50000 (26%)]	Loss: 0.813777
# Train Epoch: 36 [25728/50000 (51%)]	Loss: 0.833211
# Train Epoch: 36 [38528/50000 (77%)]	Loss: 0.985548
# Test set: Average loss: 0.0060, Accuracy: 36270/50000 (72.54%)
# Test set: Average loss: 0.0083, Accuracy: 7114/10000 (71.14%)
# Train Epoch: 37 [128/50000 (0%)]	Loss: 0.693360
# Train Epoch: 37 [12928/50000 (26%)]	Loss: 0.655490
# Train Epoch: 37 [25728/50000 (51%)]	Loss: 0.679951
# Train Epoch: 37 [38528/50000 (77%)]	Loss: 0.968580
# Test set: Average loss: 0.0060, Accuracy: 36527/50000 (73.05%)
# Test set: Average loss: 0.0082, Accuracy: 7096/10000 (70.96%)
# Train Epoch: 38 [128/50000 (0%)]	Loss: 0.821628
# Train Epoch: 38 [12928/50000 (26%)]	Loss: 0.794679
# Train Epoch: 38 [25728/50000 (51%)]	Loss: 0.739888
# Train Epoch: 38 [38528/50000 (77%)]	Loss: 0.721767
# Test set: Average loss: 0.0059, Accuracy: 36574/50000 (73.15%)
# Test set: Average loss: 0.0081, Accuracy: 7155/10000 (71.55%)
# Train Epoch: 39 [128/50000 (0%)]	Loss: 0.624685
# Train Epoch: 39 [12928/50000 (26%)]	Loss: 0.826243
# Train Epoch: 39 [25728/50000 (51%)]	Loss: 0.750928
# Train Epoch: 39 [38528/50000 (77%)]	Loss: 0.827507
# Test set: Average loss: 0.0058, Accuracy: 36821/50000 (73.64%)
# Test set: Average loss: 0.0082, Accuracy: 7170/10000 (71.70%)
# Train Epoch: 40 [128/50000 (0%)]	Loss: 0.827701
# Train Epoch: 40 [12928/50000 (26%)]	Loss: 0.788614
# Train Epoch: 40 [25728/50000 (51%)]	Loss: 0.768346
# Train Epoch: 40 [38528/50000 (77%)]	Loss: 0.782509
# Test set: Average loss: 0.0058, Accuracy: 36996/50000 (73.99%)
# Test set: Average loss: 0.0079, Accuracy: 7241/10000 (72.41%)
# Train Epoch: 41 [128/50000 (0%)]	Loss: 0.745699
# Train Epoch: 41 [12928/50000 (26%)]	Loss: 0.765621
# Train Epoch: 41 [25728/50000 (51%)]	Loss: 0.810958
# Train Epoch: 41 [38528/50000 (77%)]	Loss: 0.717485
# Test set: Average loss: 0.0058, Accuracy: 36861/50000 (73.72%)
# Test set: Average loss: 0.0081, Accuracy: 7194/10000 (71.94%)
# Train Epoch: 42 [128/50000 (0%)]	Loss: 0.780832
# Train Epoch: 42 [12928/50000 (26%)]	Loss: 0.616264
# Train Epoch: 42 [25728/50000 (51%)]	Loss: 0.574591
# Train Epoch: 42 [38528/50000 (77%)]	Loss: 0.739930
# Test set: Average loss: 0.0056, Accuracy: 37205/50000 (74.41%)
# Test set: Average loss: 0.0079, Accuracy: 7249/10000 (72.49%)
# Train Epoch: 43 [128/50000 (0%)]	Loss: 0.833213
# Train Epoch: 43 [12928/50000 (26%)]	Loss: 0.850960
# Train Epoch: 43 [25728/50000 (51%)]	Loss: 0.632403
# Train Epoch: 43 [38528/50000 (77%)]	Loss: 0.721557
# Test set: Average loss: 0.0056, Accuracy: 37271/50000 (74.54%)
# Test set: Average loss: 0.0079, Accuracy: 7244/10000 (72.44%)
# Train Epoch: 44 [128/50000 (0%)]	Loss: 0.695062
# Train Epoch: 44 [12928/50000 (26%)]	Loss: 0.821862
# Train Epoch: 44 [25728/50000 (51%)]	Loss: 0.650075
# Train Epoch: 44 [38528/50000 (77%)]	Loss: 0.828597
# Test set: Average loss: 0.0055, Accuracy: 37585/50000 (75.17%)
# Test set: Average loss: 0.0077, Accuracy: 7281/10000 (72.81%)
# Train Epoch: 45 [128/50000 (0%)]	Loss: 0.831155
# Train Epoch: 45 [12928/50000 (26%)]	Loss: 0.682887
# Train Epoch: 45 [25728/50000 (51%)]	Loss: 0.798033
# Train Epoch: 45 [38528/50000 (77%)]	Loss: 0.632390
# Test set: Average loss: 0.0054, Accuracy: 37782/50000 (75.56%)
# Test set: Average loss: 0.0077, Accuracy: 7331/10000 (73.31%)
# Train Epoch: 46 [128/50000 (0%)]	Loss: 0.810616
# Train Epoch: 46 [12928/50000 (26%)]	Loss: 0.716068
# Train Epoch: 46 [25728/50000 (51%)]	Loss: 0.640876
# Train Epoch: 46 [38528/50000 (77%)]	Loss: 0.759656
# Test set: Average loss: 0.0053, Accuracy: 37967/50000 (75.93%)
# Test set: Average loss: 0.0076, Accuracy: 7344/10000 (73.44%)
# Train Epoch: 47 [128/50000 (0%)]	Loss: 0.705559
# Train Epoch: 47 [12928/50000 (26%)]	Loss: 0.863351
# Train Epoch: 47 [25728/50000 (51%)]	Loss: 0.725882
# Train Epoch: 47 [38528/50000 (77%)]	Loss: 0.609711
# Test set: Average loss: 0.0054, Accuracy: 37832/50000 (75.66%)
# Test set: Average loss: 0.0078, Accuracy: 7313/10000 (73.13%)
# Train Epoch: 48 [128/50000 (0%)]	Loss: 0.710398
# Train Epoch: 48 [12928/50000 (26%)]	Loss: 0.573235
# Train Epoch: 48 [25728/50000 (51%)]	Loss: 0.728901
# Train Epoch: 48 [38528/50000 (77%)]	Loss: 0.814585
# Test set: Average loss: 0.0053, Accuracy: 38026/50000 (76.05%)
# Test set: Average loss: 0.0076, Accuracy: 7356/10000 (73.56%)
# Train Epoch: 49 [128/50000 (0%)]	Loss: 0.485323
# Train Epoch: 49 [12928/50000 (26%)]	Loss: 0.744516
# Train Epoch: 49 [25728/50000 (51%)]	Loss: 0.666117
# Train Epoch: 49 [38528/50000 (77%)]	Loss: 1.030518
# Test set: Average loss: 0.0052, Accuracy: 38179/50000 (76.36%)
# Test set: Average loss: 0.0075, Accuracy: 7370/10000 (73.70%)
# Train Epoch: 50 [128/50000 (0%)]	Loss: 0.749428
# Train Epoch: 50 [12928/50000 (26%)]	Loss: 0.843040
# Train Epoch: 50 [25728/50000 (51%)]	Loss: 0.649994
# Train Epoch: 50 [38528/50000 (77%)]	Loss: 0.834252
# Test set: Average loss: 0.0051, Accuracy: 38465/50000 (76.93%)
# Test set: Average loss: 0.0073, Accuracy: 7447/10000 (74.47%)
# Train Epoch: 51 [128/50000 (0%)]	Loss: 0.580429
# Train Epoch: 51 [12928/50000 (26%)]	Loss: 0.609915
# Train Epoch: 51 [25728/50000 (51%)]	Loss: 0.677186
# Train Epoch: 51 [38528/50000 (77%)]	Loss: 0.735337
# Test set: Average loss: 0.0051, Accuracy: 38514/50000 (77.03%)
# Test set: Average loss: 0.0074, Accuracy: 7402/10000 (74.02%)
# Train Epoch: 52 [128/50000 (0%)]	Loss: 0.759597
# Train Epoch: 52 [12928/50000 (26%)]	Loss: 0.556260
# Train Epoch: 52 [25728/50000 (51%)]	Loss: 0.641064
# Train Epoch: 52 [38528/50000 (77%)]	Loss: 0.631973
# Test set: Average loss: 0.0051, Accuracy: 38603/50000 (77.21%)
# Test set: Average loss: 0.0073, Accuracy: 7453/10000 (74.53%)
# Train Epoch: 53 [128/50000 (0%)]	Loss: 0.452954
# Train Epoch: 53 [12928/50000 (26%)]	Loss: 0.680411
# Train Epoch: 53 [25728/50000 (51%)]	Loss: 0.561105
# Train Epoch: 53 [38528/50000 (77%)]	Loss: 0.907493
# Test set: Average loss: 0.0050, Accuracy: 38845/50000 (77.69%)
# Test set: Average loss: 0.0072, Accuracy: 7535/10000 (75.35%)
# Train Epoch: 54 [128/50000 (0%)]	Loss: 0.859880
# Train Epoch: 54 [12928/50000 (26%)]	Loss: 0.499180
# Train Epoch: 54 [25728/50000 (51%)]	Loss: 0.757222
# Train Epoch: 54 [38528/50000 (77%)]	Loss: 0.528361
# Test set: Average loss: 0.0050, Accuracy: 38759/50000 (77.52%)
# Test set: Average loss: 0.0073, Accuracy: 7479/10000 (74.79%)
# Train Epoch: 55 [128/50000 (0%)]	Loss: 0.750937
# Train Epoch: 55 [12928/50000 (26%)]	Loss: 0.718349
# Train Epoch: 55 [25728/50000 (51%)]	Loss: 0.512140
# Train Epoch: 55 [38528/50000 (77%)]	Loss: 0.824545
# Test set: Average loss: 0.0049, Accuracy: 38933/50000 (77.87%)
# Test set: Average loss: 0.0071, Accuracy: 7526/10000 (75.26%)
# Train Epoch: 56 [128/50000 (0%)]	Loss: 0.636227
# Train Epoch: 56 [12928/50000 (26%)]	Loss: 0.616207
# Train Epoch: 56 [25728/50000 (51%)]	Loss: 0.690891
# Train Epoch: 56 [38528/50000 (77%)]	Loss: 0.751876
# Test set: Average loss: 0.0048, Accuracy: 39346/50000 (78.69%)
# Test set: Average loss: 0.0070, Accuracy: 7556/10000 (75.56%)
# Train Epoch: 57 [128/50000 (0%)]	Loss: 0.556343
# Train Epoch: 57 [12928/50000 (26%)]	Loss: 0.675694
# Train Epoch: 57 [25728/50000 (51%)]	Loss: 0.642148
# Train Epoch: 57 [38528/50000 (77%)]	Loss: 0.563654
# Test set: Average loss: 0.0049, Accuracy: 39039/50000 (78.08%)
# Test set: Average loss: 0.0072, Accuracy: 7554/10000 (75.54%)
# Train Epoch: 58 [128/50000 (0%)]	Loss: 0.691421
# Train Epoch: 58 [12928/50000 (26%)]	Loss: 0.737994
# Train Epoch: 58 [25728/50000 (51%)]	Loss: 0.667605
# Train Epoch: 58 [38528/50000 (77%)]	Loss: 0.667588
# Test set: Average loss: 0.0047, Accuracy: 39402/50000 (78.80%)
# Test set: Average loss: 0.0070, Accuracy: 7569/10000 (75.69%)
# Train Epoch: 59 [128/50000 (0%)]	Loss: 0.605395
# Train Epoch: 59 [12928/50000 (26%)]	Loss: 0.659133
# Train Epoch: 59 [25728/50000 (51%)]	Loss: 0.596724
# Train Epoch: 59 [38528/50000 (77%)]	Loss: 0.723920
# Test set: Average loss: 0.0047, Accuracy: 39424/50000 (78.85%)
# Test set: Average loss: 0.0070, Accuracy: 7592/10000 (75.92%)
# Train Epoch: 60 [128/50000 (0%)]	Loss: 0.637022
# Train Epoch: 60 [12928/50000 (26%)]	Loss: 0.738380
# Train Epoch: 60 [25728/50000 (51%)]	Loss: 0.627055
# Train Epoch: 60 [38528/50000 (77%)]	Loss: 0.684992
# Test set: Average loss: 0.0046, Accuracy: 39736/50000 (79.47%)
# Test set: Average loss: 0.0069, Accuracy: 7637/10000 (76.37%)
# Train Epoch: 61 [128/50000 (0%)]	Loss: 0.545772
# Train Epoch: 61 [12928/50000 (26%)]	Loss: 0.538021
# Train Epoch: 61 [25728/50000 (51%)]	Loss: 0.553485
# Train Epoch: 61 [38528/50000 (77%)]	Loss: 0.694535
# Test set: Average loss: 0.0045, Accuracy: 39840/50000 (79.68%)
# Test set: Average loss: 0.0069, Accuracy: 7662/10000 (76.62%)
# Train Epoch: 62 [128/50000 (0%)]	Loss: 0.590487
# Train Epoch: 62 [12928/50000 (26%)]	Loss: 0.632940
# Train Epoch: 62 [25728/50000 (51%)]	Loss: 0.600469
# Train Epoch: 62 [38528/50000 (77%)]	Loss: 0.689919
# Test set: Average loss: 0.0045, Accuracy: 39980/50000 (79.96%)
# Test set: Average loss: 0.0068, Accuracy: 7649/10000 (76.49%)
# Train Epoch: 63 [128/50000 (0%)]	Loss: 0.566514
# Train Epoch: 63 [12928/50000 (26%)]	Loss: 0.509724
# Train Epoch: 63 [25728/50000 (51%)]	Loss: 0.597111
# Train Epoch: 63 [38528/50000 (77%)]	Loss: 0.530515
# Test set: Average loss: 0.0045, Accuracy: 39951/50000 (79.90%)
# Test set: Average loss: 0.0068, Accuracy: 7666/10000 (76.66%)
# Train Epoch: 64 [128/50000 (0%)]	Loss: 0.467351
# Train Epoch: 64 [12928/50000 (26%)]	Loss: 0.596997
# Train Epoch: 64 [25728/50000 (51%)]	Loss: 0.660531
# Train Epoch: 64 [38528/50000 (77%)]	Loss: 0.648844
# Test set: Average loss: 0.0044, Accuracy: 40323/50000 (80.65%)
# Test set: Average loss: 0.0068, Accuracy: 7682/10000 (76.82%)
# Train Epoch: 65 [128/50000 (0%)]	Loss: 0.519631
# Train Epoch: 65 [12928/50000 (26%)]	Loss: 0.622074
# Train Epoch: 65 [25728/50000 (51%)]	Loss: 0.602293
# Train Epoch: 65 [38528/50000 (77%)]	Loss: 0.669505
# Test set: Average loss: 0.0044, Accuracy: 40144/50000 (80.29%)
# Test set: Average loss: 0.0068, Accuracy: 7709/10000 (77.09%)
# Train Epoch: 66 [128/50000 (0%)]	Loss: 0.557380
# Train Epoch: 66 [12928/50000 (26%)]	Loss: 0.464495
# Train Epoch: 66 [25728/50000 (51%)]	Loss: 0.486538
# Train Epoch: 66 [38528/50000 (77%)]	Loss: 0.597796
# Test set: Average loss: 0.0044, Accuracy: 40111/50000 (80.22%)
# Test set: Average loss: 0.0068, Accuracy: 7688/10000 (76.88%)
# Train Epoch: 67 [128/50000 (0%)]	Loss: 0.469825
# Train Epoch: 67 [12928/50000 (26%)]	Loss: 0.511518
# Train Epoch: 67 [25728/50000 (51%)]	Loss: 0.604846
# Train Epoch: 67 [38528/50000 (77%)]	Loss: 0.526195
# Test set: Average loss: 0.0043, Accuracy: 40423/50000 (80.85%)
# Test set: Average loss: 0.0065, Accuracy: 7824/10000 (78.24%)
# Train Epoch: 68 [128/50000 (0%)]	Loss: 0.572048
# Train Epoch: 68 [12928/50000 (26%)]	Loss: 0.564085
# Train Epoch: 68 [25728/50000 (51%)]	Loss: 0.410490
# Train Epoch: 68 [38528/50000 (77%)]	Loss: 0.706635
# Test set: Average loss: 0.0043, Accuracy: 40345/50000 (80.69%)
# Test set: Average loss: 0.0067, Accuracy: 7740/10000 (77.40%)
# Train Epoch: 69 [128/50000 (0%)]	Loss: 0.468688
# Train Epoch: 69 [12928/50000 (26%)]	Loss: 0.487202
# Train Epoch: 69 [25728/50000 (51%)]	Loss: 0.553270
# Train Epoch: 69 [38528/50000 (77%)]	Loss: 0.617551
# Test set: Average loss: 0.0042, Accuracy: 40612/50000 (81.22%)
# Test set: Average loss: 0.0065, Accuracy: 7807/10000 (78.07%)
# Train Epoch: 70 [128/50000 (0%)]	Loss: 0.489665
# Train Epoch: 70 [12928/50000 (26%)]	Loss: 0.587333
# Train Epoch: 70 [25728/50000 (51%)]	Loss: 0.575510
# Train Epoch: 70 [38528/50000 (77%)]	Loss: 0.566955
# Test set: Average loss: 0.0042, Accuracy: 40678/50000 (81.36%)
# Test set: Average loss: 0.0065, Accuracy: 7751/10000 (77.51%)
# Train Epoch: 71 [128/50000 (0%)]	Loss: 0.463042
# Train Epoch: 71 [12928/50000 (26%)]	Loss: 0.432999
# Train Epoch: 71 [25728/50000 (51%)]	Loss: 0.599345
# Train Epoch: 71 [38528/50000 (77%)]	Loss: 0.527952
# Test set: Average loss: 0.0041, Accuracy: 40750/50000 (81.50%)
# Test set: Average loss: 0.0065, Accuracy: 7801/10000 (78.01%)
# Train Epoch: 72 [128/50000 (0%)]	Loss: 0.679437
# Train Epoch: 72 [12928/50000 (26%)]	Loss: 0.580358
# Train Epoch: 72 [25728/50000 (51%)]	Loss: 0.693288
# Train Epoch: 72 [38528/50000 (77%)]	Loss: 0.450761
# Test set: Average loss: 0.0041, Accuracy: 40895/50000 (81.79%)
# Test set: Average loss: 0.0064, Accuracy: 7838/10000 (78.38%)
# Train Epoch: 73 [128/50000 (0%)]	Loss: 0.559492
# Train Epoch: 73 [12928/50000 (26%)]	Loss: 0.491316
# Train Epoch: 73 [25728/50000 (51%)]	Loss: 0.656960
# Train Epoch: 73 [38528/50000 (77%)]	Loss: 0.446576
# Test set: Average loss: 0.0040, Accuracy: 41049/50000 (82.10%)
# Test set: Average loss: 0.0064, Accuracy: 7856/10000 (78.56%)
# Train Epoch: 74 [128/50000 (0%)]	Loss: 0.473473
# Train Epoch: 74 [12928/50000 (26%)]	Loss: 0.714313
# Train Epoch: 74 [25728/50000 (51%)]	Loss: 0.645493
# Train Epoch: 74 [38528/50000 (77%)]	Loss: 0.522588
# Test set: Average loss: 0.0040, Accuracy: 40895/50000 (81.79%)
# Test set: Average loss: 0.0065, Accuracy: 7827/10000 (78.27%)
# Train Epoch: 75 [128/50000 (0%)]	Loss: 0.426818
# Train Epoch: 75 [12928/50000 (26%)]	Loss: 0.582896
# Train Epoch: 75 [25728/50000 (51%)]	Loss: 0.648693
# Train Epoch: 75 [38528/50000 (77%)]	Loss: 0.531850
# Test set: Average loss: 0.0040, Accuracy: 41114/50000 (82.23%)
# Test set: Average loss: 0.0063, Accuracy: 7885/10000 (78.85%)
# Train Epoch: 76 [128/50000 (0%)]	Loss: 0.479772
# Train Epoch: 76 [12928/50000 (26%)]	Loss: 0.589677
# Train Epoch: 76 [25728/50000 (51%)]	Loss: 0.474908
# Train Epoch: 76 [38528/50000 (77%)]	Loss: 0.590824
# Test set: Average loss: 0.0040, Accuracy: 40933/50000 (81.87%)
# Test set: Average loss: 0.0065, Accuracy: 7807/10000 (78.07%)
# Train Epoch: 77 [128/50000 (0%)]	Loss: 0.624927
# Train Epoch: 77 [12928/50000 (26%)]	Loss: 0.620336
# Train Epoch: 77 [25728/50000 (51%)]	Loss: 0.499087
# Train Epoch: 77 [38528/50000 (77%)]	Loss: 0.497194
# Test set: Average loss: 0.0039, Accuracy: 41410/50000 (82.82%)
# Test set: Average loss: 0.0062, Accuracy: 7881/10000 (78.81%)
# Train Epoch: 78 [128/50000 (0%)]	Loss: 0.558471
# Train Epoch: 78 [12928/50000 (26%)]	Loss: 0.435873
# Train Epoch: 78 [25728/50000 (51%)]	Loss: 0.483284
# Train Epoch: 78 [38528/50000 (77%)]	Loss: 0.653946
# Test set: Average loss: 0.0039, Accuracy: 41420/50000 (82.84%)
# Test set: Average loss: 0.0062, Accuracy: 7884/10000 (78.84%)
# Train Epoch: 79 [128/50000 (0%)]	Loss: 0.474184
# Train Epoch: 79 [12928/50000 (26%)]	Loss: 0.503477
# Train Epoch: 79 [25728/50000 (51%)]	Loss: 0.518168
# Train Epoch: 79 [38528/50000 (77%)]	Loss: 0.551012
# Test set: Average loss: 0.0038, Accuracy: 41431/50000 (82.86%)
# Test set: Average loss: 0.0062, Accuracy: 7949/10000 (79.49%)
# Train Epoch: 80 [128/50000 (0%)]	Loss: 0.428153
# Train Epoch: 80 [12928/50000 (26%)]	Loss: 0.402240
# Train Epoch: 80 [25728/50000 (51%)]	Loss: 0.549448
# Train Epoch: 80 [38528/50000 (77%)]	Loss: 0.325102
# Test set: Average loss: 0.0038, Accuracy: 41531/50000 (83.06%)
# Test set: Average loss: 0.0062, Accuracy: 7892/10000 (78.92%)
# Train Epoch: 81 [128/50000 (0%)]	Loss: 0.501418
# Train Epoch: 81 [12928/50000 (26%)]	Loss: 0.443091
# Train Epoch: 81 [25728/50000 (51%)]	Loss: 0.464530
# Train Epoch: 81 [38528/50000 (77%)]	Loss: 0.554287
# Test set: Average loss: 0.0038, Accuracy: 41646/50000 (83.29%)
# Test set: Average loss: 0.0062, Accuracy: 7954/10000 (79.54%)
# Train Epoch: 82 [128/50000 (0%)]	Loss: 0.411340
# Train Epoch: 82 [12928/50000 (26%)]	Loss: 0.418997
# Train Epoch: 82 [25728/50000 (51%)]	Loss: 0.528621
# Train Epoch: 82 [38528/50000 (77%)]	Loss: 0.561308
# Test set: Average loss: 0.0037, Accuracy: 41714/50000 (83.43%)
# Test set: Average loss: 0.0062, Accuracy: 7928/10000 (79.28%)
# Train Epoch: 83 [128/50000 (0%)]	Loss: 0.378393
# Train Epoch: 83 [12928/50000 (26%)]	Loss: 0.472665
# Train Epoch: 83 [25728/50000 (51%)]	Loss: 0.544059
# Train Epoch: 83 [38528/50000 (77%)]	Loss: 0.484175
# Test set: Average loss: 0.0038, Accuracy: 41544/50000 (83.09%)
# Test set: Average loss: 0.0063, Accuracy: 7873/10000 (78.73%)
# Train Epoch: 84 [128/50000 (0%)]	Loss: 0.412202
# Train Epoch: 84 [12928/50000 (26%)]	Loss: 0.541330
# Train Epoch: 84 [25728/50000 (51%)]	Loss: 0.479857
# Train Epoch: 84 [38528/50000 (77%)]	Loss: 0.435027
# Test set: Average loss: 0.0037, Accuracy: 41802/50000 (83.60%)
# Test set: Average loss: 0.0061, Accuracy: 7958/10000 (79.58%)
# Train Epoch: 85 [128/50000 (0%)]	Loss: 0.549077
# Train Epoch: 85 [12928/50000 (26%)]	Loss: 0.411720
# Train Epoch: 85 [25728/50000 (51%)]	Loss: 0.506144
# Train Epoch: 85 [38528/50000 (77%)]	Loss: 0.444760
# Test set: Average loss: 0.0037, Accuracy: 41739/50000 (83.48%)
# Test set: Average loss: 0.0062, Accuracy: 7907/10000 (79.07%)
# Train Epoch: 86 [128/50000 (0%)]	Loss: 0.592056
# Train Epoch: 86 [12928/50000 (26%)]	Loss: 0.461655
# Train Epoch: 86 [25728/50000 (51%)]	Loss: 0.461430
# Train Epoch: 86 [38528/50000 (77%)]	Loss: 0.626576
# Test set: Average loss: 0.0036, Accuracy: 42135/50000 (84.27%)
# Test set: Average loss: 0.0059, Accuracy: 8040/10000 (80.40%)
# Train Epoch: 87 [128/50000 (0%)]	Loss: 0.505772
# Train Epoch: 87 [12928/50000 (26%)]	Loss: 0.352777
# Train Epoch: 87 [25728/50000 (51%)]	Loss: 0.596873
# Train Epoch: 87 [38528/50000 (77%)]	Loss: 0.495418
# Test set: Average loss: 0.0035, Accuracy: 42088/50000 (84.18%)
# Test set: Average loss: 0.0060, Accuracy: 7981/10000 (79.81%)
# Train Epoch: 88 [128/50000 (0%)]	Loss: 0.587043
# Train Epoch: 88 [12928/50000 (26%)]	Loss: 0.511898
# Train Epoch: 88 [25728/50000 (51%)]	Loss: 0.567819
# Train Epoch: 88 [38528/50000 (77%)]	Loss: 0.464519
# Test set: Average loss: 0.0035, Accuracy: 42099/50000 (84.20%)
# Test set: Average loss: 0.0060, Accuracy: 8026/10000 (80.26%)
# Train Epoch: 89 [128/50000 (0%)]	Loss: 0.408335
# Train Epoch: 89 [12928/50000 (26%)]	Loss: 0.323261
# Train Epoch: 89 [25728/50000 (51%)]	Loss: 0.621133
# Train Epoch: 89 [38528/50000 (77%)]	Loss: 0.452796
# Test set: Average loss: 0.0035, Accuracy: 42173/50000 (84.35%)
# Test set: Average loss: 0.0061, Accuracy: 7958/10000 (79.58%)
# Train Epoch: 90 [128/50000 (0%)]	Loss: 0.449133
# Train Epoch: 90 [12928/50000 (26%)]	Loss: 0.397749
# Train Epoch: 90 [25728/50000 (51%)]	Loss: 0.624896
# Train Epoch: 90 [38528/50000 (77%)]	Loss: 0.487344
# Test set: Average loss: 0.0035, Accuracy: 42107/50000 (84.21%)
# Test set: Average loss: 0.0060, Accuracy: 8052/10000 (80.52%)
# Train Epoch: 91 [128/50000 (0%)]	Loss: 0.380625
# Train Epoch: 91 [12928/50000 (26%)]	Loss: 0.550911
# Train Epoch: 91 [25728/50000 (51%)]	Loss: 0.417285
# Train Epoch: 91 [38528/50000 (77%)]	Loss: 0.379555
# Test set: Average loss: 0.0034, Accuracy: 42426/50000 (84.85%)
# Test set: Average loss: 0.0060, Accuracy: 8015/10000 (80.15%)
# Train Epoch: 92 [128/50000 (0%)]	Loss: 0.403037
# Train Epoch: 92 [12928/50000 (26%)]	Loss: 0.446986
# Train Epoch: 92 [25728/50000 (51%)]	Loss: 0.378935
# Train Epoch: 92 [38528/50000 (77%)]	Loss: 0.444940
# Test set: Average loss: 0.0034, Accuracy: 42464/50000 (84.93%)
# Test set: Average loss: 0.0060, Accuracy: 8020/10000 (80.20%)
# Train Epoch: 93 [128/50000 (0%)]	Loss: 0.335576
# Train Epoch: 93 [12928/50000 (26%)]	Loss: 0.545865
# Train Epoch: 93 [25728/50000 (51%)]	Loss: 0.538060
# Train Epoch: 93 [38528/50000 (77%)]	Loss: 0.558598
# Test set: Average loss: 0.0034, Accuracy: 42299/50000 (84.60%)
# Test set: Average loss: 0.0060, Accuracy: 8048/10000 (80.48%)
# Train Epoch: 94 [128/50000 (0%)]	Loss: 0.475401
# Train Epoch: 94 [12928/50000 (26%)]	Loss: 0.485887
# Train Epoch: 94 [25728/50000 (51%)]	Loss: 0.332790
# Train Epoch: 94 [38528/50000 (77%)]	Loss: 0.476275
# Test set: Average loss: 0.0033, Accuracy: 42561/50000 (85.12%)
# Test set: Average loss: 0.0059, Accuracy: 8039/10000 (80.39%)
# Train Epoch: 95 [128/50000 (0%)]	Loss: 0.483304
# Train Epoch: 95 [12928/50000 (26%)]	Loss: 0.445765
# Train Epoch: 95 [25728/50000 (51%)]	Loss: 0.408825
# Train Epoch: 95 [38528/50000 (77%)]	Loss: 0.554283
# Test set: Average loss: 0.0033, Accuracy: 42569/50000 (85.14%)
# Test set: Average loss: 0.0059, Accuracy: 8085/10000 (80.85%)
# Train Epoch: 96 [128/50000 (0%)]	Loss: 0.317540
# Train Epoch: 96 [12928/50000 (26%)]	Loss: 0.463071
# Train Epoch: 96 [25728/50000 (51%)]	Loss: 0.338906
# Train Epoch: 96 [38528/50000 (77%)]	Loss: 0.349908
# Test set: Average loss: 0.0034, Accuracy: 42498/50000 (85.00%)
# Test set: Average loss: 0.0059, Accuracy: 8054/10000 (80.54%)
# Train Epoch: 97 [128/50000 (0%)]	Loss: 0.461753
# Train Epoch: 97 [12928/50000 (26%)]	Loss: 0.314438
# Train Epoch: 97 [25728/50000 (51%)]	Loss: 0.348627
# Train Epoch: 97 [38528/50000 (77%)]	Loss: 0.392967
# Test set: Average loss: 0.0033, Accuracy: 42662/50000 (85.32%)
# Test set: Average loss: 0.0058, Accuracy: 8059/10000 (80.59%)
# Train Epoch: 98 [128/50000 (0%)]	Loss: 0.267960
# Train Epoch: 98 [12928/50000 (26%)]	Loss: 0.452204
# Train Epoch: 98 [25728/50000 (51%)]	Loss: 0.341330
# Train Epoch: 98 [38528/50000 (77%)]	Loss: 0.398683
# Test set: Average loss: 0.0033, Accuracy: 42575/50000 (85.15%)
# Test set: Average loss: 0.0059, Accuracy: 8061/10000 (80.61%)
# Train Epoch: 99 [128/50000 (0%)]	Loss: 0.365953
# Train Epoch: 99 [12928/50000 (26%)]	Loss: 0.614803
# Train Epoch: 99 [25728/50000 (51%)]	Loss: 0.340974
# Train Epoch: 99 [38528/50000 (77%)]	Loss: 0.457783
# Test set: Average loss: 0.0033, Accuracy: 42587/50000 (85.17%)
# Test set: Average loss: 0.0059, Accuracy: 8075/10000 (80.75%)
# Train Epoch: 100 [128/50000 (0%)]	Loss: 0.329514
# Train Epoch: 100 [12928/50000 (26%)]	Loss: 0.514080
# Train Epoch: 100 [25728/50000 (51%)]	Loss: 0.477614
# Train Epoch: 100 [38528/50000 (77%)]	Loss: 0.452880
# Test set: Average loss: 0.0032, Accuracy: 42891/50000 (85.78%)
# Test set: Average loss: 0.0059, Accuracy: 8082/10000 (80.82%)
# Train Epoch: 101 [128/50000 (0%)]	Loss: 0.578575
# Train Epoch: 101 [12928/50000 (26%)]	Loss: 0.475360
# Train Epoch: 101 [25728/50000 (51%)]	Loss: 0.463228
# Train Epoch: 101 [38528/50000 (77%)]	Loss: 0.423506
# Test set: Average loss: 0.0032, Accuracy: 42845/50000 (85.69%)
# Test set: Average loss: 0.0058, Accuracy: 8105/10000 (81.05%)
# Train Epoch: 102 [128/50000 (0%)]	Loss: 0.460764
# Train Epoch: 102 [12928/50000 (26%)]	Loss: 0.388433
# Train Epoch: 102 [25728/50000 (51%)]	Loss: 0.360392
# Train Epoch: 102 [38528/50000 (77%)]	Loss: 0.489587
# Test set: Average loss: 0.0032, Accuracy: 42844/50000 (85.69%)
# Test set: Average loss: 0.0059, Accuracy: 8061/10000 (80.61%)
# Train Epoch: 103 [128/50000 (0%)]	Loss: 0.356605
# Train Epoch: 103 [12928/50000 (26%)]	Loss: 0.483693
# Train Epoch: 103 [25728/50000 (51%)]	Loss: 0.412526
# Train Epoch: 103 [38528/50000 (77%)]	Loss: 0.503860
# Test set: Average loss: 0.0032, Accuracy: 42809/50000 (85.62%)
# Test set: Average loss: 0.0059, Accuracy: 8088/10000 (80.88%)
# Train Epoch: 104 [128/50000 (0%)]	Loss: 0.418720
# Train Epoch: 104 [12928/50000 (26%)]	Loss: 0.493631
# Train Epoch: 104 [25728/50000 (51%)]	Loss: 0.431047
# Train Epoch: 104 [38528/50000 (77%)]	Loss: 0.435753
# Test set: Average loss: 0.0032, Accuracy: 43035/50000 (86.07%)
# Test set: Average loss: 0.0059, Accuracy: 8084/10000 (80.84%)
# Train Epoch: 105 [128/50000 (0%)]	Loss: 0.459166
# Train Epoch: 105 [12928/50000 (26%)]	Loss: 0.295160
# Train Epoch: 105 [25728/50000 (51%)]	Loss: 0.445879
# Train Epoch: 105 [38528/50000 (77%)]	Loss: 0.525196
# Test set: Average loss: 0.0031, Accuracy: 43216/50000 (86.43%)
# Test set: Average loss: 0.0058, Accuracy: 8087/10000 (80.87%)
# Train Epoch: 106 [128/50000 (0%)]	Loss: 0.453892
# Train Epoch: 106 [12928/50000 (26%)]	Loss: 0.498837
# Train Epoch: 106 [25728/50000 (51%)]	Loss: 0.397970
# Train Epoch: 106 [38528/50000 (77%)]	Loss: 0.331943
# Test set: Average loss: 0.0031, Accuracy: 43103/50000 (86.21%)
# Test set: Average loss: 0.0059, Accuracy: 8102/10000 (81.02%)
# Train Epoch: 107 [128/50000 (0%)]	Loss: 0.280272
# Train Epoch: 107 [12928/50000 (26%)]	Loss: 0.434437
# Train Epoch: 107 [25728/50000 (51%)]	Loss: 0.394211
# Train Epoch: 107 [38528/50000 (77%)]	Loss: 0.405427
# Test set: Average loss: 0.0031, Accuracy: 43133/50000 (86.27%)
# Test set: Average loss: 0.0059, Accuracy: 8086/10000 (80.86%)
# Train Epoch: 108 [128/50000 (0%)]	Loss: 0.309960
# Train Epoch: 108 [12928/50000 (26%)]	Loss: 0.328183
# Train Epoch: 108 [25728/50000 (51%)]	Loss: 0.481001
# Train Epoch: 108 [38528/50000 (77%)]	Loss: 0.445557
# Test set: Average loss: 0.0030, Accuracy: 43215/50000 (86.43%)
# Test set: Average loss: 0.0057, Accuracy: 8131/10000 (81.31%)
# Train Epoch: 109 [128/50000 (0%)]	Loss: 0.396317
# Train Epoch: 109 [12928/50000 (26%)]	Loss: 0.261743
# Train Epoch: 109 [25728/50000 (51%)]	Loss: 0.495289
# Train Epoch: 109 [38528/50000 (77%)]	Loss: 0.328131
# Test set: Average loss: 0.0030, Accuracy: 43337/50000 (86.67%)
# Test set: Average loss: 0.0058, Accuracy: 8118/10000 (81.18%)
# Train Epoch: 110 [128/50000 (0%)]	Loss: 0.420920
# Train Epoch: 110 [12928/50000 (26%)]	Loss: 0.421609
# Train Epoch: 110 [25728/50000 (51%)]	Loss: 0.422606
# Train Epoch: 110 [38528/50000 (77%)]	Loss: 0.477761
# Test set: Average loss: 0.0030, Accuracy: 43329/50000 (86.66%)
# Test set: Average loss: 0.0059, Accuracy: 8101/10000 (81.01%)
# Train Epoch: 111 [128/50000 (0%)]	Loss: 0.519671
# Train Epoch: 111 [12928/50000 (26%)]	Loss: 0.365627
# Train Epoch: 111 [25728/50000 (51%)]	Loss: 0.349254
# Train Epoch: 111 [38528/50000 (77%)]	Loss: 0.474175
# Test set: Average loss: 0.0029, Accuracy: 43483/50000 (86.97%)
# Test set: Average loss: 0.0058, Accuracy: 8117/10000 (81.17%)
# Train Epoch: 112 [128/50000 (0%)]	Loss: 0.510908
# Train Epoch: 112 [12928/50000 (26%)]	Loss: 0.528916
# Train Epoch: 112 [25728/50000 (51%)]	Loss: 0.380931
# Train Epoch: 112 [38528/50000 (77%)]	Loss: 0.430959
# Test set: Average loss: 0.0030, Accuracy: 43343/50000 (86.69%)
# Test set: Average loss: 0.0057, Accuracy: 8152/10000 (81.52%)
# Train Epoch: 113 [128/50000 (0%)]	Loss: 0.528443
# Train Epoch: 113 [12928/50000 (26%)]	Loss: 0.484663
# Train Epoch: 113 [25728/50000 (51%)]	Loss: 0.367618
# Train Epoch: 113 [38528/50000 (77%)]	Loss: 0.314406
# Test set: Average loss: 0.0029, Accuracy: 43569/50000 (87.14%)
# Test set: Average loss: 0.0057, Accuracy: 8111/10000 (81.11%)
# Train Epoch: 114 [128/50000 (0%)]	Loss: 0.377170
# Train Epoch: 114 [12928/50000 (26%)]	Loss: 0.429634
# Train Epoch: 114 [25728/50000 (51%)]	Loss: 0.288174
# Train Epoch: 114 [38528/50000 (77%)]	Loss: 0.429015
# Test set: Average loss: 0.0029, Accuracy: 43469/50000 (86.94%)
# Test set: Average loss: 0.0059, Accuracy: 8111/10000 (81.11%)
# Train Epoch: 115 [128/50000 (0%)]	Loss: 0.372842
# Train Epoch: 115 [12928/50000 (26%)]	Loss: 0.414265
# Train Epoch: 115 [25728/50000 (51%)]	Loss: 0.494146
# Train Epoch: 115 [38528/50000 (77%)]	Loss: 0.409864
# Test set: Average loss: 0.0028, Accuracy: 43586/50000 (87.17%)
# Test set: Average loss: 0.0056, Accuracy: 8156/10000 (81.56%)
# Train Epoch: 116 [128/50000 (0%)]	Loss: 0.376659
# Train Epoch: 116 [12928/50000 (26%)]	Loss: 0.413616
# Train Epoch: 116 [25728/50000 (51%)]	Loss: 0.414257
# Train Epoch: 116 [38528/50000 (77%)]	Loss: 0.453455
# Test set: Average loss: 0.0029, Accuracy: 43379/50000 (86.76%)
# Test set: Average loss: 0.0059, Accuracy: 8126/10000 (81.26%)
# Train Epoch: 117 [128/50000 (0%)]	Loss: 0.381500
# Train Epoch: 117 [12928/50000 (26%)]	Loss: 0.420376
# Train Epoch: 117 [25728/50000 (51%)]	Loss: 0.276637
# Train Epoch: 117 [38528/50000 (77%)]	Loss: 0.477886
# Test set: Average loss: 0.0029, Accuracy: 43595/50000 (87.19%)
# Test set: Average loss: 0.0058, Accuracy: 8107/10000 (81.07%)
# Train Epoch: 118 [128/50000 (0%)]	Loss: 0.462348
# Train Epoch: 118 [12928/50000 (26%)]	Loss: 0.344013
# Train Epoch: 118 [25728/50000 (51%)]	Loss: 0.332748
# Train Epoch: 118 [38528/50000 (77%)]	Loss: 0.353627
# Test set: Average loss: 0.0028, Accuracy: 43665/50000 (87.33%)
# Test set: Average loss: 0.0057, Accuracy: 8128/10000 (81.28%)
# Train Epoch: 119 [128/50000 (0%)]	Loss: 0.401192
# Train Epoch: 119 [12928/50000 (26%)]	Loss: 0.457352
# Train Epoch: 119 [25728/50000 (51%)]	Loss: 0.284293
# Train Epoch: 119 [38528/50000 (77%)]	Loss: 0.454690
# Test set: Average loss: 0.0028, Accuracy: 43599/50000 (87.20%)
# Test set: Average loss: 0.0058, Accuracy: 8139/10000 (81.39%)
# Train Epoch: 120 [128/50000 (0%)]	Loss: 0.326846
# Train Epoch: 120 [12928/50000 (26%)]	Loss: 0.429660
# Train Epoch: 120 [25728/50000 (51%)]	Loss: 0.343340
# Train Epoch: 120 [38528/50000 (77%)]	Loss: 0.396815
# Test set: Average loss: 0.0027, Accuracy: 43914/50000 (87.83%)
# Test set: Average loss: 0.0056, Accuracy: 8147/10000 (81.47%)
# Train Epoch: 121 [128/50000 (0%)]	Loss: 0.502482
# Train Epoch: 121 [12928/50000 (26%)]	Loss: 0.509276
# Train Epoch: 121 [25728/50000 (51%)]	Loss: 0.307923
# Train Epoch: 121 [38528/50000 (77%)]	Loss: 0.438777
# Test set: Average loss: 0.0027, Accuracy: 43867/50000 (87.73%)
# Test set: Average loss: 0.0057, Accuracy: 8173/10000 (81.73%)
# Train Epoch: 122 [128/50000 (0%)]	Loss: 0.264834
# Train Epoch: 122 [12928/50000 (26%)]	Loss: 0.324895
# Train Epoch: 122 [25728/50000 (51%)]	Loss: 0.495045
# Train Epoch: 122 [38528/50000 (77%)]	Loss: 0.443434
# Test set: Average loss: 0.0028, Accuracy: 43710/50000 (87.42%)
# Test set: Average loss: 0.0058, Accuracy: 8169/10000 (81.69%)
# Train Epoch: 123 [128/50000 (0%)]	Loss: 0.273960
# Train Epoch: 123 [12928/50000 (26%)]	Loss: 0.443935
# Train Epoch: 123 [25728/50000 (51%)]	Loss: 0.420709
# Train Epoch: 123 [38528/50000 (77%)]	Loss: 0.540388
# Test set: Average loss: 0.0027, Accuracy: 43925/50000 (87.85%)
# Test set: Average loss: 0.0057, Accuracy: 8129/10000 (81.29%)
# Train Epoch: 124 [128/50000 (0%)]	Loss: 0.421130
# Train Epoch: 124 [12928/50000 (26%)]	Loss: 0.363624
# Train Epoch: 124 [25728/50000 (51%)]	Loss: 0.297975
# Train Epoch: 124 [38528/50000 (77%)]	Loss: 0.396030
# Test set: Average loss: 0.0028, Accuracy: 43734/50000 (87.47%)
# Test set: Average loss: 0.0058, Accuracy: 8139/10000 (81.39%)
# Train Epoch: 125 [128/50000 (0%)]	Loss: 0.267315
# Train Epoch: 125 [12928/50000 (26%)]	Loss: 0.302768
# Train Epoch: 125 [25728/50000 (51%)]	Loss: 0.381721
# Train Epoch: 125 [38528/50000 (77%)]	Loss: 0.417302
# Test set: Average loss: 0.0027, Accuracy: 43997/50000 (87.99%)
# Test set: Average loss: 0.0056, Accuracy: 8192/10000 (81.92%)

# %%
def softmax_by_row(logits, T = 1.0):
    mx = np.max(logits, axis=-1, keepdims=True)
    exp = np.exp((logits - mx)/T)
    denominator = np.sum(exp, axis=-1, keepdims=True)
    return exp/denominator

def classifier_performance(model, train_loader, test_loader):

    output_train_benign = []
    train_label = []
    for num, data in enumerate(train_loader):
        images,labels = data
        image_tensor= images.to(device)
        img_variable = Variable(image_tensor, requires_grad=True)
        output = model.forward(img_variable)
        output = output.view(-1, 10)
        train_label.append(labels.numpy())
        output_train_benign.append(softmax_by_row(output.data.cpu().numpy(),T = 1))


    train_label = np.concatenate(train_label)
    output_train_benign=np.concatenate(output_train_benign)

    test_label = []
    output_test_benign = []

    for num, data in enumerate(test_loader):
        images,labels = data

        image_tensor= images.to(device)
        img_variable = Variable(image_tensor, requires_grad=True)

        output = model.forward(img_variable)
        output = output.view(-1, 10)
        test_label.append(labels.numpy())
        output_test_benign.append(softmax_by_row(output.data.cpu().numpy(),T = 1))


    test_label = np.concatenate(test_label)
    output_test_benign=np.concatenate(output_test_benign)


    train_acc1 = np.sum(np.argmax(output_train_benign,axis=1) == train_label.flatten())/len(train_label)
    test_acc1 = np.sum(np.argmax(output_test_benign,axis=1) == test_label.flatten())/len(test_label)

    print('Accuracy: ', (train_acc1, test_acc1))

    return output_train_benign, output_test_benign, train_label, test_label




def inference_via_confidence(confidence_mtx1, confidence_mtx2, label_vec1, label_vec2):
    
    #----------------First step: obtain confidence lists for both training dataset and test dataset--------------
    confidence1 = []
    confidence2 = []
    acc1 = 0
    acc2 = 0
    for num in range(confidence_mtx1.shape[0]):
        confidence1.append(confidence_mtx1[num,label_vec1[num]])
        if np.argmax(confidence_mtx1[num,:]) == label_vec1[num]:
            acc1 += 1
            
    for num in range(confidence_mtx2.shape[0]):
        confidence2.append(confidence_mtx2[num,label_vec2[num]])
        if np.argmax(confidence_mtx2[num,:]) == label_vec2[num]:
            acc2 += 1
    confidence1 = np.array(confidence1)
    confidence2 = np.array(confidence2)
    
    print('model accuracy for training and test-', (acc1/confidence_mtx1.shape[0], acc2/confidence_mtx2.shape[0]) )
    
    
    #sort_confidence = np.sort(confidence1)
    sort_confidence = np.sort(np.concatenate((confidence1, confidence2)))
    max_accuracy = 0.5
    best_precision = 0.5
    best_recall = 0.5
    for num in range(len(sort_confidence)):
        delta = sort_confidence[num]
        ratio1 = np.sum(confidence1>=delta)/confidence_mtx1.shape[0]
        ratio2 = np.sum(confidence2>=delta)/confidence_mtx2.shape[0]
        accuracy_now = 0.5*(ratio1+1-ratio2)
        if accuracy_now > max_accuracy:
            max_accuracy = accuracy_now
            best_precision = ratio1/(ratio1+ratio2)
            best_recall = ratio1
    print('membership inference accuracy is:', max_accuracy)
    return max_accuracy

# %%
from torch.autograd import Variable
import os
import numpy as np
import math 
import scipy
import sys  

output_train, output_test, train_label, test_label = classifier_performance(net, train_loader, test_loader)
inference_accuracy=inference_via_confidence(output_train, output_test, train_label, test_label)
print("Maximum Accuracy:",inference_accuracy)
# Out:
# Accuracy:  (0.88212, 0.8192)
# model accuracy for training and test- (0.88212, 0.8192)
# membership inference accuracy is: 0.53071
# Maximum Accuracy: 0.53071
