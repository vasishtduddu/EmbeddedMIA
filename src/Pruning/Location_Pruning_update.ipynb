# %%
from __future__ import print_function


import argparse
import os
import shutil
import time
import random
import torch.nn.functional as F

import argparse
import os
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.nn import Parameter
from torch.nn.modules.module import Module
import torch.nn.functional as F
from torchvision import datasets, transforms
import math

import numpy as np
import torch
from torch.nn import Parameter
from torch.nn.modules.module import Module
import torch.nn.functional as F
import torch.nn as nn
import torch.nn.functional as F


import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import numpy as np
import torch.utils.data as Data
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
class PruningModule(Module):
    def prune_by_percentile(self, q=5.0, **kwargs):
        """
        Note:
             The pruning percentile is based on all layer's parameters concatenated
        Args:
            q (float): percentile in float
            **kwargs: may contain `cuda`
        """
        # Calculate percentile value
        alive_parameters = []
        for name, p in self.named_parameters():
            # We do not prune bias term
            if 'bias' in name or 'mask' in name:
                continue
            tensor = p.data.cpu().numpy()
            alive = tensor[np.nonzero(tensor)] # flattened array of nonzero values
            alive_parameters.append(alive)

        all_alives = np.concatenate(alive_parameters)
        percentile_value = np.percentile(abs(all_alives), q)
        print(f'Pruning with threshold : {percentile_value}')

        # Prune the weights and mask
        # Note that module here is the layer
        # ex) fc1, fc2, fc3
        for name, module in self.named_modules():
            if name in ['fc1', 'fc2', 'fc3']:
                module.prune(threshold=percentile_value)

    def prune_by_std(self, s=0.25):
        """
        Note that `s` is a quality parameter / sensitivity value according to the paper.
        According to Song Han's previous paper (Learning both Weights and Connections for Efficient Neural Networks),
        'The pruning threshold is chosen as a quality parameter multiplied by the standard deviation of a layer’s weights'

        I tried multiple values and empirically, 0.25 matches the paper's compression rate and number of parameters.
        Note : In the paper, the authors used different sensitivity values for different layers.
        """
        for name, module in self.named_modules():
            if name in ['fc1', 'fc2', 'fc3']:
                threshold = np.std(module.weight.data.cpu().numpy()) * s
                print(f'Pruning with threshold : {threshold} for layer {name}')
                module.prune(threshold)


class MaskedLinear(Module):
    r"""Applies a masked linear transformation to the incoming data: :math:`y = (A * M)x + b`

    Args:
        in_features: size of each input sample
        out_features: size of each output sample
        bias: If set to False, the layer will not learn an additive bias.
            Default: ``True``

    Shape:
        - Input: :math:`(N, *, in\_features)` where `*` means any number of
          additional dimensions
        - Output: :math:`(N, *, out\_features)` where all but the last dimension
          are the same shape as the input.

    Attributes:
        weight: the learnable weights of the module of shape
            (out_features x in_features)
        bias:   the learnable bias of the module of shape (out_features)
        mask: the unlearnable mask for the weight.
            It has the same shape as weight (out_features x in_features)

    """
    def __init__(self, in_features, out_features, bias=True):
        super(MaskedLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.Tensor(out_features, in_features))
        # Initialize the mask with 1
        self.mask = Parameter(torch.ones([out_features, in_features]), requires_grad=False)
        if bias:
            self.bias = Parameter(torch.Tensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input):
        return F.linear(input, self.weight * self.mask, self.bias)

    def __repr__(self):
        return self.__class__.__name__ + '(' \
            + 'in_features=' + str(self.in_features) \
            + ', out_features=' + str(self.out_features) \
            + ', bias=' + str(self.bias is not None) + ')'

    def prune(self, threshold):
        weight_dev = self.weight.device
        mask_dev = self.mask.device
        # Convert Tensors to numpy and calculate
        tensor = self.weight.data.cpu().numpy()
        mask = self.mask.data.cpu().numpy()
        new_mask = np.where(abs(tensor) < threshold, 0, mask)
        # Apply new weight and mask
        self.weight.data = torch.from_numpy(tensor * new_mask).to(weight_dev)
        self.mask.data = torch.from_numpy(new_mask).to(mask_dev)

# %%
def print_model_parameters(model, with_values=False):
    print(f"{'Param name':20} {'Shape':30} {'Type':15}")
    print('-'*70)
    for name, param in model.named_parameters():
        print(f'{name:20} {str(param.shape):30} {str(param.dtype):15}')
        if with_values:
            print(param)


def print_nonzeros(model):
    nonzero = total = 0
    for name, p in model.named_parameters():
        if 'mask' in name:
            continue
        tensor = p.data.cpu().numpy()
        nz_count = np.count_nonzero(tensor)
        total_params = np.prod(tensor.shape)
        nonzero += nz_count
        total += total_params
        print(f'{name:20} | nonzeros = {nz_count:7} / {total_params:7} ({100 * nz_count / total_params:6.2f}%) | total_pruned = {total_params - nz_count :7} | shape = {tensor.shape}')
    print(f'alive: {nonzero}, pruned : {total - nonzero}, total: {total}, Compression rate : {total/nonzero:10.2f}x  ({100 * (total-nonzero) / total:6.2f}% pruned)')

# %%
def softmax_by_row(logits, T = 1.0):
    mx = np.max(logits, axis=-1, keepdims=True)
    exp = np.exp((logits - mx)/T)
    denominator = np.sum(exp, axis=-1, keepdims=True)
    return exp/denominator

def classifier_performance(model, train_loader, test_loader):

    output_train_benign = []
    train_label = []
    for num, data in enumerate(train_loader):
        images,labels = data
        image_tensor= images.to(device)
        img_variable = Variable(image_tensor, requires_grad=True)
        output = model.forward(img_variable)

        train_label.append(labels.numpy())
        output_train_benign.append(softmax_by_row(output.data.cpu().numpy(),T = 1))


    train_label = np.concatenate(train_label)
    output_train_benign=np.concatenate(output_train_benign)

    test_label = []
    output_test_benign = []

    for num, data in enumerate(test_loader):
        images,labels = data

        image_tensor= images.to(device)
        img_variable = Variable(image_tensor, requires_grad=True)

        output = model.forward(img_variable)

        test_label.append(labels.numpy())
        output_test_benign.append(softmax_by_row(output.data.cpu().numpy(),T = 1))


    test_label = np.concatenate(test_label)
    output_test_benign=np.concatenate(output_test_benign)


    train_acc1 = np.sum(np.argmax(output_train_benign,axis=1) == train_label.flatten())/len(train_label)
    test_acc1 = np.sum(np.argmax(output_test_benign,axis=1) == test_label.flatten())/len(test_label)

    print('Accuracy: ', (train_acc1, test_acc1))

    return output_train_benign, output_test_benign, train_label, test_label




def inference_via_confidence(confidence_mtx1, confidence_mtx2, label_vec1, label_vec2):
    
    #----------------First step: obtain confidence lists for both training dataset and test dataset--------------
    confidence1 = []
    confidence2 = []
    acc1 = 0
    acc2 = 0
    for num in range(confidence_mtx1.shape[0]):
        confidence1.append(confidence_mtx1[num,label_vec1[num]])
        if np.argmax(confidence_mtx1[num,:]) == label_vec1[num]:
            acc1 += 1
            
    for num in range(confidence_mtx2.shape[0]):
        confidence2.append(confidence_mtx2[num,label_vec2[num]])
        if np.argmax(confidence_mtx2[num,:]) == label_vec2[num]:
            acc2 += 1
    confidence1 = np.array(confidence1)
    confidence2 = np.array(confidence2)
    
    print('model accuracy for training and test-', (acc1/confidence_mtx1.shape[0], acc2/confidence_mtx2.shape[0]) )
    
    
    #sort_confidence = np.sort(confidence1)
    sort_confidence = np.sort(np.concatenate((confidence1, confidence2)))
    max_accuracy = 0.5
    best_precision = 0.5
    best_recall = 0.5
    for num in range(len(sort_confidence)):
        delta = sort_confidence[num]
        ratio1 = np.sum(confidence1>=delta)/confidence_mtx1.shape[0]
        ratio2 = np.sum(confidence2>=delta)/confidence_mtx2.shape[0]
        accuracy_now = 0.5*(ratio1+1-ratio2)
        if accuracy_now > max_accuracy:
            max_accuracy = accuracy_now
            best_precision = ratio1/(ratio1+ratio2)
            best_recall = ratio1
    print('membership inference accuracy is:', max_accuracy)
    return max_accuracy

# %%
from google.colab import drive
drive.mount('/content/gdrive')
colab='Colab Notebooks'
path = F"/content/gdrive/My Drive/{colab}/bangkok"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
print("Loading dataset...")
data_set =np.genfromtxt(path,delimiter=',')
print("Dataset loaded.")
# Out:
# Loading dataset...
# Dataset loaded.

# %%
from sklearn.model_selection import train_test_split
from torch.autograd import Variable
from sklearn.metrics import accuracy_score, precision_score, recall_score

X = data_set[:,1:].astype(np.float64)
Y = (data_set[:,0]).astype(np.int32)-1


x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.45)


train_dataset = Data.TensorDataset(torch.from_numpy(x_train).float(), torch.from_numpy(y_train).long())
test_dataset = Data.TensorDataset(torch.from_numpy(x_test).float(),  torch.from_numpy(y_test).long())


trainloader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=128, shuffle=True)
testloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=1000, shuffle=True)

# %%
batch_size=128
test_batch_size=1000
epochs=50
lr=1e-3
seed=123
log_interval=100


class PurchaseClassifier(PruningModule):
    def __init__(self, mask=False):
        super(PurchaseClassifier, self).__init__()
        linear = MaskedLinear if mask else nn.Linear
        self.fc1=linear(446,512)
        self.fc3=linear(512,256)
        self.fc4=linear(256,128)
        self.tanh = nn.Tanh()
        self.fc5=nn.Linear(128,30)
        self.softmax = nn.Softmax(dim=1)

    def forward(self,x):
        x = self.fc1(x)
        x = self.tanh(x)
        x = self.fc3(x)
        x = self.tanh(x)
        x = self.fc4(x)
        x = self.tanh(x)
        x = self.fc5(x)
        #x = self.softmax(x)
        return x

# %%
def train(epochs, model):
    model.train()
    for epoch in range(epochs):

        for batch_idx, (data, target) in enumerate(trainloader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()

            # zero-out all the gradients corresponding to the pruned connections
            for name, p in model.named_parameters():
                if 'mask' in name:
                    continue
                tensor = p.data.cpu().numpy()
                grad_tensor = p.grad.data.cpu().numpy()
                grad_tensor = np.where(tensor==0, 0, grad_tensor)
                p.grad.data = torch.from_numpy(grad_tensor).to(device)

            optimizer.step()
            if batch_idx % log_interval == 0:
                done = batch_idx * len(data)
                percentage = 100. * batch_idx / len(trainloader)
                print(f'Train Epoch: {epoch} [{done:5}/{len(trainloader.dataset)} ({percentage:3.0f}%)]  Loss: {loss.item():.6f}')
        test(trainloader, model)
        test(testloader, model)

def test(loader, model):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item() # sum up batch loss
            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).sum().item()

        test_loss /= len(loader.dataset)
        accuracy = 100. * correct / len(loader.dataset)
        print(f'Test set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(loader.dataset)} ({accuracy:.2f}%)')
    return accuracy

# %%
model = PurchaseClassifier(mask=True).cuda()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

print_model_parameters(model)

# NOTE : `weight_decay` term denotes L2 regularization loss term
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.000)
initial_optimizer_state_dict = optimizer.state_dict()
# Out:
# Param name           Shape                          Type
# ----------------------------------------------------------------------
# fc1.weight           torch.Size([512, 446])         torch.float32
# fc1.mask             torch.Size([512, 446])         torch.float32
# fc1.bias             torch.Size([512])              torch.float32
# fc3.weight           torch.Size([256, 512])         torch.float32
# fc3.mask             torch.Size([256, 512])         torch.float32
# fc3.bias             torch.Size([256])              torch.float32
# fc4.weight           torch.Size([128, 256])         torch.float32
# fc4.mask             torch.Size([128, 256])         torch.float32
# fc4.bias             torch.Size([128])              torch.float32
# fc5.weight           torch.Size([30, 128])          torch.float32
# fc5.bias             torch.Size([30])               torch.float32

# %% [markdown]
# #Initial Training

# %%
# Initial training
print("--- Initial training ---")
train(epochs, model)



print("--- Before pruning ---")
print_nonzeros(model)

output_train, output_test, train_label, test_label = classifier_performance(model, trainloader, testloader)
inference_accuracy=inference_via_confidence(output_train, output_test, train_label, test_label)
print("Maximum Accuracy:",inference_accuracy)
# Out:
# --- Initial training ---
# Train Epoch: 0 [    0/2755 (  0%)]  Loss: 3.399497
# Test set: Average loss: 0.0173, Accuracy: 1130/2755 (41.02%)
# Test set: Average loss: 0.0030, Accuracy: 836/2255 (37.07%)
# Train Epoch: 1 [    0/2755 (  0%)]  Loss: 2.153235
# Test set: Average loss: 0.0112, Accuracy: 1787/2755 (64.86%)
# Test set: Average loss: 0.0021, Accuracy: 1211/2255 (53.70%)
# Train Epoch: 2 [    0/2755 (  0%)]  Loss: 1.372443
# Test set: Average loss: 0.0082, Accuracy: 2057/2755 (74.66%)
# Test set: Average loss: 0.0018, Accuracy: 1311/2255 (58.14%)
# Train Epoch: 3 [    0/2755 (  0%)]  Loss: 1.102731
# Test set: Average loss: 0.0062, Accuracy: 2304/2755 (83.63%)
# Test set: Average loss: 0.0016, Accuracy: 1405/2255 (62.31%)
# Train Epoch: 4 [    0/2755 (  0%)]  Loss: 0.843570
# Test set: Average loss: 0.0048, Accuracy: 2423/2755 (87.95%)
# Test set: Average loss: 0.0015, Accuracy: 1419/2255 (62.93%)
# Train Epoch: 5 [    0/2755 (  0%)]  Loss: 0.656587
# Test set: Average loss: 0.0038, Accuracy: 2552/2755 (92.63%)
# Test set: Average loss: 0.0015, Accuracy: 1436/2255 (63.68%)
# Train Epoch: 6 [    0/2755 (  0%)]  Loss: 0.483580
# Test set: Average loss: 0.0030, Accuracy: 2621/2755 (95.14%)
# Test set: Average loss: 0.0014, Accuracy: 1429/2255 (63.37%)
# Train Epoch: 7 [    0/2755 (  0%)]  Loss: 0.325088
# Test set: Average loss: 0.0023, Accuracy: 2680/2755 (97.28%)
# Test set: Average loss: 0.0014, Accuracy: 1445/2255 (64.08%)
# Train Epoch: 8 [    0/2755 (  0%)]  Loss: 0.284399
# Test set: Average loss: 0.0019, Accuracy: 2700/2755 (98.00%)
# Test set: Average loss: 0.0014, Accuracy: 1450/2255 (64.30%)
# Train Epoch: 9 [    0/2755 (  0%)]  Loss: 0.256801
# Test set: Average loss: 0.0015, Accuracy: 2732/2755 (99.17%)
# Test set: Average loss: 0.0015, Accuracy: 1447/2255 (64.17%)
# Train Epoch: 10 [    0/2755 (  0%)]  Loss: 0.163980
# Test set: Average loss: 0.0012, Accuracy: 2742/2755 (99.53%)
# Test set: Average loss: 0.0014, Accuracy: 1431/2255 (63.46%)
# Train Epoch: 11 [    0/2755 (  0%)]  Loss: 0.151720
# Test set: Average loss: 0.0009, Accuracy: 2748/2755 (99.75%)
# Test set: Average loss: 0.0015, Accuracy: 1434/2255 (63.59%)
# Train Epoch: 12 [    0/2755 (  0%)]  Loss: 0.108026
# Test set: Average loss: 0.0008, Accuracy: 2752/2755 (99.89%)
# Test set: Average loss: 0.0015, Accuracy: 1420/2255 (62.97%)
# Train Epoch: 13 [    0/2755 (  0%)]  Loss: 0.083941
# Test set: Average loss: 0.0007, Accuracy: 2753/2755 (99.93%)
# Test set: Average loss: 0.0016, Accuracy: 1434/2255 (63.59%)
# Train Epoch: 14 [    0/2755 (  0%)]  Loss: 0.083941
# Test set: Average loss: 0.0005, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1424/2255 (63.15%)
# Train Epoch: 15 [    0/2755 (  0%)]  Loss: 0.068677
# Test set: Average loss: 0.0004, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1428/2255 (63.33%)
# Train Epoch: 16 [    0/2755 (  0%)]  Loss: 0.051787
# Test set: Average loss: 0.0004, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1415/2255 (62.75%)
# Train Epoch: 17 [    0/2755 (  0%)]  Loss: 0.055871
# Test set: Average loss: 0.0003, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1415/2255 (62.75%)
# Train Epoch: 18 [    0/2755 (  0%)]  Loss: 0.040367
# Test set: Average loss: 0.0003, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0017, Accuracy: 1429/2255 (63.37%)
# Train Epoch: 19 [    0/2755 (  0%)]  Loss: 0.040908
# Test set: Average loss: 0.0003, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1417/2255 (62.84%)
# Train Epoch: 20 [    0/2755 (  0%)]  Loss: 0.034000
# Test set: Average loss: 0.0002, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1417/2255 (62.84%)
# Train Epoch: 21 [    0/2755 (  0%)]  Loss: 0.027015
# Test set: Average loss: 0.0002, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0016, Accuracy: 1421/2255 (63.02%)
# Train Epoch: 22 [    0/2755 (  0%)]  Loss: 0.027305
# Test set: Average loss: 0.0002, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0018, Accuracy: 1411/2255 (62.57%)
# Train Epoch: 23 [    0/2755 (  0%)]  Loss: 0.023437
# Test set: Average loss: 0.0002, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0017, Accuracy: 1414/2255 (62.71%)
# Train Epoch: 24 [    0/2755 (  0%)]  Loss: 0.023181
# Test set: Average loss: 0.0002, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0017, Accuracy: 1405/2255 (62.31%)
# Train Epoch: 25 [    0/2755 (  0%)]  Loss: 0.023131
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0017, Accuracy: 1406/2255 (62.35%)
# Train Epoch: 26 [    0/2755 (  0%)]  Loss: 0.017991
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0017, Accuracy: 1410/2255 (62.53%)
# Train Epoch: 27 [    0/2755 (  0%)]  Loss: 0.017254
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0018, Accuracy: 1407/2255 (62.39%)
# Train Epoch: 28 [    0/2755 (  0%)]  Loss: 0.013816
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0017, Accuracy: 1414/2255 (62.71%)
# Train Epoch: 29 [    0/2755 (  0%)]  Loss: 0.013711
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1400/2255 (62.08%)
# Train Epoch: 30 [    0/2755 (  0%)]  Loss: 0.014065
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0018, Accuracy: 1403/2255 (62.22%)
# Train Epoch: 31 [    0/2755 (  0%)]  Loss: 0.011897
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1406/2255 (62.35%)
# Train Epoch: 32 [    0/2755 (  0%)]  Loss: 0.011633
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1406/2255 (62.35%)
# Train Epoch: 33 [    0/2755 (  0%)]  Loss: 0.011472
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0018, Accuracy: 1399/2255 (62.04%)
# Train Epoch: 34 [    0/2755 (  0%)]  Loss: 0.011570
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1402/2255 (62.17%)
# Train Epoch: 35 [    0/2755 (  0%)]  Loss: 0.010238
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1395/2255 (61.86%)
# Train Epoch: 36 [    0/2755 (  0%)]  Loss: 0.008055
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1401/2255 (62.13%)
# Train Epoch: 37 [    0/2755 (  0%)]  Loss: 0.008394
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0018, Accuracy: 1397/2255 (61.95%)
# Train Epoch: 38 [    0/2755 (  0%)]  Loss: 0.008019
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1404/2255 (62.26%)
# Train Epoch: 39 [    0/2755 (  0%)]  Loss: 0.007340
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0020, Accuracy: 1396/2255 (61.91%)
# Train Epoch: 40 [    0/2755 (  0%)]  Loss: 0.007366
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1404/2255 (62.26%)
# Train Epoch: 41 [    0/2755 (  0%)]  Loss: 0.007349
# Test set: Average loss: 0.0001, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1395/2255 (61.86%)
# Train Epoch: 42 [    0/2755 (  0%)]  Loss: 0.007632
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1393/2255 (61.77%)
# Train Epoch: 43 [    0/2755 (  0%)]  Loss: 0.006060
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1395/2255 (61.86%)
# Train Epoch: 44 [    0/2755 (  0%)]  Loss: 0.005555
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1402/2255 (62.17%)
# Train Epoch: 45 [    0/2755 (  0%)]  Loss: 0.006227
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0020, Accuracy: 1395/2255 (61.86%)
# Train Epoch: 46 [    0/2755 (  0%)]  Loss: 0.004705
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0020, Accuracy: 1393/2255 (61.77%)
# Train Epoch: 47 [    0/2755 (  0%)]  Loss: 0.004904
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0020, Accuracy: 1396/2255 (61.91%)
# Train Epoch: 48 [    0/2755 (  0%)]  Loss: 0.004828
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0019, Accuracy: 1396/2255 (61.91%)
# Train Epoch: 49 [    0/2755 (  0%)]  Loss: 0.004810
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test set: Average loss: 0.0020, Accuracy: 1387/2255 (61.51%)
# --- Before pruning ---
# fc1.weight           | nonzeros =  228352 /  228352 (100.00%) | total_pruned =       0 | shape = (512, 446)
# fc1.bias             | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# fc3.weight           | nonzeros =  131072 /  131072 (100.00%) | total_pruned =       0 | shape = (256, 512)
# fc3.bias             | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# fc4.weight           | nonzeros =   32768 /   32768 (100.00%) | total_pruned =       0 | shape = (128, 256)
# fc4.bias             | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# fc5.weight           | nonzeros =    3840 /    3840 (100.00%) | total_pruned =       0 | shape = (30, 128)
# fc5.bias             | nonzeros =      30 /      30 (100.00%) | total_pruned =       0 | shape = (30,)
# alive: 396958, pruned : 0, total: 396958, Compression rate :       1.00x  (  0.00% pruned)
# Accuracy:  (1.0, 0.6150776053215078)
# model accuracy for training and test- (1.0, 0.6150776053215078)
# membership inference accuracy is: 0.8343024776560256
# Maximum Accuracy: 0.8343024776560256

# %%
from google.colab import drive
drive.mount('/content/gdrive')
model_save_name = 'location.pt'
colab='Colab Notebooks'
path = F"/content/gdrive/My Drive/{colab}/{model_save_name}" 
torch.save(model.state_dict(), path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **Pruning**

# %%
model_save_name = 'location.pt'
colab='Colab Notebooks'
path = F"/content/gdrive/My Drive/{colab}/{model_save_name}" 
temp = PurchaseClassifier(mask=True).cuda()
temp.load_state_dict(torch.load(path))
test_accuracy = test(testloader, temp)
train_accuracy = test(trainloader, temp)
print("Test Accuracy:", test_accuracy)
print("Train Accuracy:", train_accuracy)
# Out:
# Test set: Average loss: 0.0020, Accuracy: 1387/2255 (61.51%)
# Test set: Average loss: 0.0000, Accuracy: 2755/2755 (100.00%)
# Test Accuracy: 61.507760532150776
# Train Accuracy: 100.0

# %%
print("--- Starting pruning ---")
temp.prune_by_std(2.75)
test_accuracy = test(testloader,temp)
train_accuracy = test(trainloader, temp)
print("Test Accuracy:", test_accuracy)
print("Train Accuracy:", train_accuracy)
print("--- After pruning ---")
print_nonzeros(temp)

output_train, output_test, train_label, test_label = classifier_performance(temp, trainloader, testloader)
inference_accuracy=inference_via_confidence(output_train, output_test, train_label, test_label)
print("Maximum Accuracy:",inference_accuracy)
# Out:
# --- Starting pruning ---
# Pruning with threshold : 0.12122122012078762 for layer fc1
# Pruning with threshold : 0.15917067416012287 for layer fc3
# Test set: Average loss: 0.0046, Accuracy: 69/2255 (3.06%)
# Test set: Average loss: 0.0274, Accuracy: 86/2755 (3.12%)
# Test Accuracy: 3.059866962305987
# Train Accuracy: 3.1215970961887476
# --- After pruning ---
# fc1.weight           | nonzeros =    1087 /  228352 (  0.48%) | total_pruned =  227265 | shape = (512, 446)
# fc1.bias             | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# fc3.weight           | nonzeros =     474 /  131072 (  0.36%) | total_pruned =  130598 | shape = (256, 512)
# fc3.bias             | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# fc4.weight           | nonzeros =   32768 /   32768 (100.00%) | total_pruned =       0 | shape = (128, 256)
# fc4.bias             | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# fc5.weight           | nonzeros =    3840 /    3840 (100.00%) | total_pruned =       0 | shape = (30, 128)
# fc5.bias             | nonzeros =      30 /      30 (100.00%) | total_pruned =       0 | shape = (30,)
# alive: 39095, pruned : 357863, total: 396958, Compression rate :      10.15x  ( 90.15% pruned)
# Accuracy:  (0.03121597096188748, 0.030598669623059866)
# model accuracy for training and test- (0.03121597096188748, 0.030598669623059866)
# membership inference accuracy is: 0.5260763538174896
# Maximum Accuracy: 0.5260763538174896

# %% [markdown]
# # **Retraining**

# %%
print("--- Retraining ---")
#optimizer.load_state_dict(initial_optimizer_state_dict) # Reset the optimizer
optimizer = optim.Adam(temp.parameters(), lr=0.001)
train(epochs, temp)


print("--- After Retraining ---")
print_nonzeros(temp)

output_train, output_test, train_label, test_label = classifier_performance(temp, trainloader, testloader)
inference_accuracy=inference_via_confidence(output_train, output_test, train_label, test_label)
print("Maximum Accuracy:",inference_accuracy)
# Out:
# --- Retraining ---
# Train Epoch: 0 [    0/2755 (  0%)]  Loss: 3.426635
# Test set: Average loss: 0.0253, Accuracy: 302/2755 (10.96%)
# Test set: Average loss: 0.0043, Accuracy: 230/2255 (10.20%)
# Train Epoch: 1 [    0/2755 (  0%)]  Loss: 3.171105
# Test set: Average loss: 0.0241, Accuracy: 500/2755 (18.15%)
# Test set: Average loss: 0.0041, Accuracy: 350/2255 (15.52%)
# Train Epoch: 2 [    0/2755 (  0%)]  Loss: 3.044307
# Test set: Average loss: 0.0225, Accuracy: 628/2755 (22.79%)
# Test set: Average loss: 0.0038, Accuracy: 443/2255 (19.65%)
# Train Epoch: 3 [    0/2755 (  0%)]  Loss: 2.766274
# Test set: Average loss: 0.0207, Accuracy: 817/2755 (29.66%)
# Test set: Average loss: 0.0036, Accuracy: 542/2255 (24.04%)
# Train Epoch: 4 [    0/2755 (  0%)]  Loss: 2.660913
# Test set: Average loss: 0.0189, Accuracy: 1003/2755 (36.41%)
# Test set: Average loss: 0.0034, Accuracy: 662/2255 (29.36%)
# Train Epoch: 5 [    0/2755 (  0%)]  Loss: 2.275954
# Test set: Average loss: 0.0172, Accuracy: 1148/2755 (41.67%)
# Test set: Average loss: 0.0031, Accuracy: 747/2255 (33.13%)
# Train Epoch: 6 [    0/2755 (  0%)]  Loss: 2.116062
# Test set: Average loss: 0.0158, Accuracy: 1237/2755 (44.90%)
# Test set: Average loss: 0.0030, Accuracy: 802/2255 (35.57%)
# Train Epoch: 7 [    0/2755 (  0%)]  Loss: 1.921792
# Test set: Average loss: 0.0148, Accuracy: 1289/2755 (46.79%)
# Test set: Average loss: 0.0028, Accuracy: 833/2255 (36.94%)
# Train Epoch: 8 [    0/2755 (  0%)]  Loss: 1.812302
# Test set: Average loss: 0.0139, Accuracy: 1343/2755 (48.75%)
# Test set: Average loss: 0.0028, Accuracy: 849/2255 (37.65%)
# Train Epoch: 9 [    0/2755 (  0%)]  Loss: 1.710137
# Test set: Average loss: 0.0132, Accuracy: 1402/2755 (50.89%)
# Test set: Average loss: 0.0027, Accuracy: 883/2255 (39.16%)
# Train Epoch: 10 [    0/2755 (  0%)]  Loss: 1.726495
# Test set: Average loss: 0.0126, Accuracy: 1429/2755 (51.87%)
# Test set: Average loss: 0.0027, Accuracy: 914/2255 (40.53%)
# Train Epoch: 11 [    0/2755 (  0%)]  Loss: 1.667673
# Test set: Average loss: 0.0122, Accuracy: 1484/2755 (53.87%)
# Test set: Average loss: 0.0026, Accuracy: 923/2255 (40.93%)
# Train Epoch: 12 [    0/2755 (  0%)]  Loss: 1.423113
# Test set: Average loss: 0.0116, Accuracy: 1501/2755 (54.48%)
# Test set: Average loss: 0.0025, Accuracy: 951/2255 (42.17%)
# Train Epoch: 13 [    0/2755 (  0%)]  Loss: 1.432655
# Test set: Average loss: 0.0113, Accuracy: 1554/2755 (56.41%)
# Test set: Average loss: 0.0025, Accuracy: 968/2255 (42.93%)
# Train Epoch: 14 [    0/2755 (  0%)]  Loss: 1.602510
# Test set: Average loss: 0.0110, Accuracy: 1583/2755 (57.46%)
# Test set: Average loss: 0.0025, Accuracy: 973/2255 (43.15%)
# Train Epoch: 15 [    0/2755 (  0%)]  Loss: 1.574340
# Test set: Average loss: 0.0108, Accuracy: 1589/2755 (57.68%)
# Test set: Average loss: 0.0025, Accuracy: 975/2255 (43.24%)
# Train Epoch: 16 [    0/2755 (  0%)]  Loss: 1.358611
# Test set: Average loss: 0.0106, Accuracy: 1616/2755 (58.66%)
# Test set: Average loss: 0.0025, Accuracy: 987/2255 (43.77%)
# Train Epoch: 17 [    0/2755 (  0%)]  Loss: 1.237271
# Test set: Average loss: 0.0103, Accuracy: 1625/2755 (58.98%)
# Test set: Average loss: 0.0024, Accuracy: 987/2255 (43.77%)
# Train Epoch: 18 [    0/2755 (  0%)]  Loss: 1.095876
# Test set: Average loss: 0.0101, Accuracy: 1649/2755 (59.85%)
# Test set: Average loss: 0.0025, Accuracy: 1003/2255 (44.48%)
# Train Epoch: 19 [    0/2755 (  0%)]  Loss: 1.293070
# Test set: Average loss: 0.0100, Accuracy: 1680/2755 (60.98%)
# Test set: Average loss: 0.0025, Accuracy: 997/2255 (44.21%)
# Train Epoch: 20 [    0/2755 (  0%)]  Loss: 1.321237
# Test set: Average loss: 0.0098, Accuracy: 1688/2755 (61.27%)
# Test set: Average loss: 0.0024, Accuracy: 1004/2255 (44.52%)
# Train Epoch: 21 [    0/2755 (  0%)]  Loss: 1.335020
# Test set: Average loss: 0.0096, Accuracy: 1693/2755 (61.45%)
# Test set: Average loss: 0.0024, Accuracy: 1004/2255 (44.52%)
# Train Epoch: 22 [    0/2755 (  0%)]  Loss: 1.147804
# Test set: Average loss: 0.0095, Accuracy: 1712/2755 (62.14%)
# Test set: Average loss: 0.0024, Accuracy: 1007/2255 (44.66%)
# Train Epoch: 23 [    0/2755 (  0%)]  Loss: 1.287469
# Test set: Average loss: 0.0094, Accuracy: 1735/2755 (62.98%)
# Test set: Average loss: 0.0024, Accuracy: 1019/2255 (45.19%)
# Train Epoch: 24 [    0/2755 (  0%)]  Loss: 1.073659
# Test set: Average loss: 0.0093, Accuracy: 1733/2755 (62.90%)
# Test set: Average loss: 0.0024, Accuracy: 1020/2255 (45.23%)
# Train Epoch: 25 [    0/2755 (  0%)]  Loss: 1.448073
# Test set: Average loss: 0.0091, Accuracy: 1762/2755 (63.96%)
# Test set: Average loss: 0.0024, Accuracy: 1023/2255 (45.37%)
# Train Epoch: 26 [    0/2755 (  0%)]  Loss: 1.022025
# Test set: Average loss: 0.0091, Accuracy: 1745/2755 (63.34%)
# Test set: Average loss: 0.0024, Accuracy: 1002/2255 (44.43%)
# Train Epoch: 27 [    0/2755 (  0%)]  Loss: 1.093881
# Test set: Average loss: 0.0089, Accuracy: 1783/2755 (64.72%)
# Test set: Average loss: 0.0025, Accuracy: 1011/2255 (44.83%)
# Train Epoch: 28 [    0/2755 (  0%)]  Loss: 1.263134
# Test set: Average loss: 0.0088, Accuracy: 1764/2755 (64.03%)
# Test set: Average loss: 0.0025, Accuracy: 1011/2255 (44.83%)
# Train Epoch: 29 [    0/2755 (  0%)]  Loss: 1.048449
# Test set: Average loss: 0.0087, Accuracy: 1805/2755 (65.52%)
# Test set: Average loss: 0.0024, Accuracy: 1014/2255 (44.97%)
# Train Epoch: 30 [    0/2755 (  0%)]  Loss: 1.036702
# Test set: Average loss: 0.0085, Accuracy: 1826/2755 (66.28%)
# Test set: Average loss: 0.0025, Accuracy: 1020/2255 (45.23%)
# Train Epoch: 31 [    0/2755 (  0%)]  Loss: 1.105999
# Test set: Average loss: 0.0084, Accuracy: 1830/2755 (66.42%)
# Test set: Average loss: 0.0025, Accuracy: 1024/2255 (45.41%)
# Train Epoch: 32 [    0/2755 (  0%)]  Loss: 0.955386
# Test set: Average loss: 0.0083, Accuracy: 1841/2755 (66.82%)
# Test set: Average loss: 0.0025, Accuracy: 1028/2255 (45.59%)
# Train Epoch: 33 [    0/2755 (  0%)]  Loss: 0.934657
# Test set: Average loss: 0.0082, Accuracy: 1852/2755 (67.22%)
# Test set: Average loss: 0.0025, Accuracy: 1026/2255 (45.50%)
# Train Epoch: 34 [    0/2755 (  0%)]  Loss: 0.986323
# Test set: Average loss: 0.0082, Accuracy: 1864/2755 (67.66%)
# Test set: Average loss: 0.0025, Accuracy: 1021/2255 (45.28%)
# Train Epoch: 35 [    0/2755 (  0%)]  Loss: 0.771828
# Test set: Average loss: 0.0081, Accuracy: 1885/2755 (68.42%)
# Test set: Average loss: 0.0024, Accuracy: 1027/2255 (45.54%)
# Train Epoch: 36 [    0/2755 (  0%)]  Loss: 0.759668
# Test set: Average loss: 0.0079, Accuracy: 1879/2755 (68.20%)
# Test set: Average loss: 0.0024, Accuracy: 1023/2255 (45.37%)
# Train Epoch: 37 [    0/2755 (  0%)]  Loss: 1.112473
# Test set: Average loss: 0.0079, Accuracy: 1866/2755 (67.73%)
# Test set: Average loss: 0.0025, Accuracy: 1016/2255 (45.06%)
# Train Epoch: 38 [    0/2755 (  0%)]  Loss: 0.910283
# Test set: Average loss: 0.0078, Accuracy: 1907/2755 (69.22%)
# Test set: Average loss: 0.0025, Accuracy: 1019/2255 (45.19%)
# Train Epoch: 39 [    0/2755 (  0%)]  Loss: 0.783489
# Test set: Average loss: 0.0077, Accuracy: 1913/2755 (69.44%)
# Test set: Average loss: 0.0025, Accuracy: 1029/2255 (45.63%)
# Train Epoch: 40 [    0/2755 (  0%)]  Loss: 0.838656
# Test set: Average loss: 0.0076, Accuracy: 1925/2755 (69.87%)
# Test set: Average loss: 0.0024, Accuracy: 1021/2255 (45.28%)
# Train Epoch: 41 [    0/2755 (  0%)]  Loss: 0.965432
# Test set: Average loss: 0.0076, Accuracy: 1923/2755 (69.80%)
# Test set: Average loss: 0.0025, Accuracy: 1024/2255 (45.41%)
# Train Epoch: 42 [    0/2755 (  0%)]  Loss: 1.011232
# Test set: Average loss: 0.0075, Accuracy: 1938/2755 (70.34%)
# Test set: Average loss: 0.0026, Accuracy: 1035/2255 (45.90%)
# Train Epoch: 43 [    0/2755 (  0%)]  Loss: 0.831650
# Test set: Average loss: 0.0075, Accuracy: 1944/2755 (70.56%)
# Test set: Average loss: 0.0026, Accuracy: 1034/2255 (45.85%)
# Train Epoch: 44 [    0/2755 (  0%)]  Loss: 0.925568
# Test set: Average loss: 0.0073, Accuracy: 1960/2755 (71.14%)
# Test set: Average loss: 0.0026, Accuracy: 1034/2255 (45.85%)
# Train Epoch: 45 [    0/2755 (  0%)]  Loss: 0.896864
# Test set: Average loss: 0.0073, Accuracy: 1960/2755 (71.14%)
# Test set: Average loss: 0.0025, Accuracy: 1027/2255 (45.54%)
# Train Epoch: 46 [    0/2755 (  0%)]  Loss: 0.957565
# Test set: Average loss: 0.0072, Accuracy: 1962/2755 (71.22%)
# Test set: Average loss: 0.0026, Accuracy: 1029/2255 (45.63%)
# Train Epoch: 47 [    0/2755 (  0%)]  Loss: 0.877525
# Test set: Average loss: 0.0071, Accuracy: 1984/2755 (72.01%)
# Test set: Average loss: 0.0027, Accuracy: 1030/2255 (45.68%)
# Train Epoch: 48 [    0/2755 (  0%)]  Loss: 0.922362
# Test set: Average loss: 0.0071, Accuracy: 1988/2755 (72.16%)
# Test set: Average loss: 0.0027, Accuracy: 1020/2255 (45.23%)
# Train Epoch: 49 [    0/2755 (  0%)]  Loss: 0.808718
# Test set: Average loss: 0.0069, Accuracy: 1996/2755 (72.45%)
# Test set: Average loss: 0.0026, Accuracy: 1034/2255 (45.85%)
# --- After Retraining ---
# fc1.weight           | nonzeros =    1087 /  228352 (  0.48%) | total_pruned =  227265 | shape = (512, 446)
# fc1.bias             | nonzeros =     512 /     512 (100.00%) | total_pruned =       0 | shape = (512,)
# fc3.weight           | nonzeros =     474 /  131072 (  0.36%) | total_pruned =  130598 | shape = (256, 512)
# fc3.bias             | nonzeros =     256 /     256 (100.00%) | total_pruned =       0 | shape = (256,)
# fc4.weight           | nonzeros =   32768 /   32768 (100.00%) | total_pruned =       0 | shape = (128, 256)
# fc4.bias             | nonzeros =     128 /     128 (100.00%) | total_pruned =       0 | shape = (128,)
# fc5.weight           | nonzeros =    3840 /    3840 (100.00%) | total_pruned =       0 | shape = (30, 128)
# fc5.bias             | nonzeros =      30 /      30 (100.00%) | total_pruned =       0 | shape = (30,)
# alive: 39095, pruned : 357863, total: 396958, Compression rate :      10.15x  ( 90.15% pruned)
# Accuracy:  (0.7245009074410164, 0.4585365853658537)
# model accuracy for training and test- (0.7245009074410164, 0.4585365853658537)
# membership inference accuracy is: 0.6402791135649355
# Maximum Accuracy: 0.6402791135649355
